# %%
# This is a sample Python script.

# Press ⌃R to execute it or replace it with your code.
# Press Double ⇧ to search everywhere for classes, files, tool windows, actions, and settings.
#Import pandas
import pandas as pd
import time
import re
import string
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
import nltk
from nltk.corpus import wordnet
from collections import Counter

#Instantiate Stemmer
stemmer = PorterStemmer()
def word_stemmer(text):
    stem_text = [stemmer.stem(i) for i in text]
    return stem_text
def get_part_of_speech(word):
    probable_part_of_speech = wordnet.synsets(word)
    pos_counts = Counter()
    pos_counts["n"] = len([item for item in probable_part_of_speech if item.pos() == "n"])
    pos_counts["v"] = len([item for item in probable_part_of_speech if item.pos() == "v"])
    pos_counts["a"] = len([item for item in probable_part_of_speech if item.pos() == "a"])
    pos_counts["r"] = len([item for item in probable_part_of_speech if item.pos() == "r"])

    most_likely_part_of_speech = pos_counts.most_common(1)[0][0]
    return most_likely_part_of_speech

# Instantiate lemmatizer
lemmatizer = WordNetLemmatizer()
def word_lemmatizer(text):
    lem_text = [lemmatizer.lemmatize(i, get_part_of_speech(i)) for i in text]
    return lem_text

def removeNumber(text):
    return' '.join(re.sub(r'[0-9]',' ', text).split())
def deEmojify(text):
    return text.encode('ascii', 'ignore').decode('ascii')
def remove_stopwords(text):
    stpwrd = nltk.corpus.stopwords.words('english')
    text = text.split(" ")
    words = [w for w in text if w not in stpwrd]
    return ' '.join(words)
def removePunctuation(text):
    no_punc = "".join([c for c in text if c not in string.punctuation])
    return no_punc
def removeLink(text):
    no_link = ' '.join(re.sub("(w+://S+)", " ", text).split())
    return no_link
def preprocess(content): #res -> clean_content
    clean_content = content.lower()
    # removeLinks
    clean_content = removeLink(clean_content)
    # remove stop words
    clean_content = remove_stopwords(clean_content)
    # removePunc
    clean_content = removePunctuation(clean_content)
    # removeEmojis
    clean_content = deEmojify(clean_content)
    # removeNumber
    clean_content = removeNumber(clean_content)
    # tokenizer
    tokenizer = RegexpTokenizer(r'\w+|\$[\d\.]+|\S+')
    clean_content = tokenizer.tokenize(clean_content)
    # lemmatizer
    clean_content = word_lemmatizer(clean_content)
    # stemmer
    #clean_content = word_stemmer(clean_content)
    return clean_content
def prepare_data(dataset):
#prepare_data(df, stemmer='lan', spellcheck=False):
    start_time = time.time()
    dataset['clean_content'] = [preprocess(x) for x in dataset['content']]
    #if spellcheck: df.to_csv("/Users/neel/Desktop/bigsample_spellchecked.csv")
    print("--- %s seconds ---" % (time.time() - start_time))
    return dataset
def get_data(file):
    data = pd.read_csv(file)
    print(data.shape)
    return data

# %%
file = "final_annotations.csv"
# prepare the data
print("preprocessing data...")
dataset = prepare_data(get_data(file))
print("done preprocessing data...")
print(len(dataset))
# Out:
# preprocessing data...
# (3097, 16)
# --- 1.239717960357666 seconds ---
# done preprocessing data...
# 3097

# %%
df = dataset.query("aacat1 not in ['Noise', 'none']")
#df['aacat1'].unique()
corpus_list = df['clean_content'].tolist()
#corpus_list
# Out:
# [['need',
#   'notice',
#   'alexa',
#   'go',
#   'add',
#   'comment',
#   'command',
#   'im',
#   'hard',
#   'hearing'],
#  ['give',
#   'app',
#   'constantly',
#   'go',
#   'offline',
#   'multiple',
#   'device',
#   'sign',
#   'sign',
#   'use',
#   'app',
#   'app',
#   'tell',
#   'echo',
#   'plus',
#   'line',
#   'yet',
#   'device',
#   'connect',
#   'work',
#   'correctly',
#   'reset',
#   'echo',
#   'multiple',
#   'time',
#   'create',
#   'new',
#   'account',
#   'reinstall',
#   'app',
#   'multiple',
#   'device',
#   'result',
#   'account',
#   'constantly',
#   'go',
#   'line',
#   'send',
#   'numerous',
#   'email',
#   'help',
#   'desk',
#   'reply',
#   'believe',
#   'account',
#   'server',
#   'issue',
#   'amazon',
#   'honest',
#   'user',
#   'echo',
#   'device',
#   'still',
#   'work',
#   'fine',
#   'capable',
#   'voice',
#   'control',
#   'light',
#   'etc',
#   'replace',
#   'competitor',
#   'product',
#   'stage',
#   'never',
#   'recommend',
#   'product',
#   'anyone'],
#  ['im',
#   'addict',
#   'didnt',
#   'even',
#   'want',
#   'alexa',
#   'memory',
#   'companion',
#   'im',
#   'alone',
#   'lol'],
#  ['must',
#   'repeat',
#   'request',
#   'would',
#   'like',
#   'frustrate',
#   'time',
#   'otherwise',
#   'convenient',
#   'addictive'],
#  ['love',
#   'device',
#   'kind',
#   'addict',
#   'them',
#   'help',
#   'stay',
#   'organize',
#   'time',
#   'thing',
#   'wish',
#   'would',
#   'change',
#   'allow',
#   'set',
#   'personalize',
#   'wake',
#   'word',
#   'lot',
#   'choice',
#   'wake',
#   'word',
#   'even',
#   'celebrity',
#   'voice',
#   'would',
#   'cool'],
#  ['india',
#   'limit',
#   'feature',
#   'offer',
#   'pure',
#   'example',
#   'discrimination',
#   'u',
#   'many',
#   'feature',
#   'like',
#   'energy',
#   'dashboard',
#   'hunch',
#   'etc',
#   'india',
#   'pay',
#   'amount',
#   'money',
#   'echo',
#   'device',
#   'thus',
#   'deserve',
#   'feature'],
#  ['good', 'minus', 'privacy', 'issue'],
#  ['want',
#   'app',
#   'privacy',
#   'concern',
#   'give',
#   'kind',
#   'choice',
#   'would',
#   'download',
#   'it',
#   'amazon',
#   'bloatware',
#   'need',
#   'for',
#   'space',
#   'leave',
#   'kindle',
#   'fire',
#   'update',
#   'apps',
#   'actually',
#   'want',
#   'use',
#   'force',
#   'installation',
#   'alexa',
#   'make',
#   'kindle',
#   'fire',
#   'absolutely',
#   'useless',
#   'me',
#   'buy',
#   'another',
#   'amazon',
#   'tablet',
#   'due',
#   'ongoing',
#   'problem',
#   'ive',
#   'force',
#   'download',
#   'proprietary',
#   'software',
#   'need',
#   'prevent',
#   'thing',
#   'actually',
#   'want',
#   'need',
#   'tablet',
#   'for'],
#  ['invasive',
#   'always',
#   'listen',
#   'rarely',
#   'want',
#   'often',
#   'inappropriate',
#   'response',
#   'tv',
#   'dialogue',
#   'stay',
#   'away',
#   'waste',
#   'money',
#   'also',
#   'give',
#   'lot',
#   'privacy'],
#  ['easy',
#   'set',
#   'tablet',
#   'call',
#   'message',
#   'setup',
#   'come',
#   'app',
#   'cellphone',
#   'tablet',
#   'call',
#   'message',
#   'feature',
#   'skill',
#   'setup',
#   'slightly',
#   'challenge',
#   'absence',
#   'print',
#   'instruction',
#   'box',
#   'dot',
#   'smart',
#   'plug',
#   'connect',
#   'device',
#   'enable',
#   'control',
#   'alexa',
#   'minute',
#   'change',
#   'abbreviate',
#   'name',
#   'full',
#   'name',
#   'alexa',
#   'recognize',
#   'complete',
#   'command',
#   'impress',
#   'limit',
#   'use',
#   'employ',
#   'far',
#   'next',
#   'test',
#   'disconnect',
#   'power',
#   'reconnecting',
#   'determine',
#   'continuity',
#   'setup',
#   'connection',
#   'amazon',
#   'echo',
#   'service',
#   'since',
#   'intend',
#   'dot',
#   'connect',
#   'privacy',
#   'consideration'],
#  ['like',
#   'set',
#   'automatic',
#   'reminder',
#   'thing',
#   'like',
#   'leave',
#   'work',
#   'now',
#   'phone',
#   'app',
#   'way',
#   'figure',
#   'use',
#   'alexa',
#   'device',
#   'fear',
#   'privacy',
#   'often',
#   'sometimes',
#   'think',
#   'disconnect',
#   'it'],
#  ['like',
#   'cortana',
#   'bad',
#   'oh',
#   'amazon',
#   'spy',
#   'everything',
#   'phone',
#   'disgust',
#   'invasion',
#   'privacy',
#   'never',
#   'trust',
#   'scummy',
#   'market',
#   'company'],
#  ['honesty',
#   'ask',
#   'this',
#   'want',
#   'all',
#   'like',
#   'washington',
#   'post',
#   'app',
#   'instal',
#   'device',
#   'without',
#   'consent',
#   'subscribe',
#   'forum',
#   'tag',
#   'like',
#   'that',
#   'especially',
#   'since',
#   'well',
#   'know',
#   'tag',
#   'trace',
#   'program',
#   'like',
#   'that',
#   'pure',
#   'violation',
#   'privacy',
#   'like',
#   'app',
#   'recommend',
#   'it',
#   'give',
#   'good',
#   'rat',
#   'like',
#   'im',
#   'apparently',
#   'allow',
#   'uninstall',
#   'delete',
#   'update',
#   'program',
#   'app',
#   'program',
#   'itself',
#   'use',
#   'it',
#   'ever',
#   'dead',
#   'weight',
#   'data',
#   'filler',
#   'good',
#   'ride',
#   'of'],
#  ['time', 'alexa', 'mind', 'own', 'interrupt', 'privacy'],
#  ['alexa',
#   'store',
#   'audio',
#   'hear',
#   'even',
#   'havent',
#   'speak',
#   'name',
#   'find',
#   'audio',
#   'record',
#   'clearly',
#   'target',
#   'alexa',
#   'didnt',
#   'semblance',
#   'wake',
#   'word',
#   'app',
#   'massive',
#   'invasion',
#   'privacy'],
#  ['dont',
#   'usebuy',
#   'app',
#   'intrusive',
#   'privacy',
#   'thing',
#   'speaker',
#   'sonos',
#   'go',
#   'nut',
#   'come',
#   'sonos',
#   'speaker',
#   'app',
#   'take',
#   'instruction',
#   'go',
#   'on',
#   'unless',
#   'set',
#   'account',
#   'even',
#   'though',
#   'wife',
#   'account',
#   'stay',
#   'clear',
#   'super',
#   'unhappy',
#   'combination',
#   'sonos',
#   'alexa',
#   'lose',
#   'hour',
#   'today',
#   'sonos',
#   'update'],
#  ['ever',
#   'since',
#   'update',
#   'app',
#   'long',
#   'able',
#   'access',
#   'feature',
#   'app',
#   'without',
#   'give',
#   'access',
#   'contact',
#   'privacy',
#   'overreach',
#   'im',
#   'delete',
#   'app',
#   'start',
#   'cancel',
#   'amazon',
#   'service',
#   'unacceptable'],
#  ['alright',
#   'amazon',
#   'low',
#   'life',
#   'privacy',
#   'invade',
#   'hack',
#   'since',
#   'first',
#   'september',
#   'bluetooth',
#   'headset',
#   'due',
#   'fact',
#   'state',
#   'institute',
#   'handsfree',
#   'law',
#   'now',
#   'whenever',
#   'im',
#   'somewhere',
#   'quiet',
#   'hear',
#   'faintest',
#   'static',
#   'come',
#   'earpiece',
#   'similar',
#   'one',
#   'phone',
#   'call',
#   'think',
#   'nothing',
#   'it',
#   'minute',
#   'ago',
#   'whilst',
#   'wear',
#   'headset',
#   'choose',
#   'uninstall',
#   'last',
#   'amazon',
#   'app',
#   'phone',
#   'onestatic',
#   'disappear',
#   'soon',
#   'uninst'],
#  ['invasive',
#   'go',
#   'randomly',
#   'without',
#   'prompt',
#   'gather',
#   'info',
#   'unless',
#   'manually',
#   'turn',
#   'off',
#   'respect',
#   'privacy',
#   'much',
#   'ai'],
#  ['amount',
#   'privacy',
#   'need',
#   'give',
#   'overhyped',
#   'egg',
#   'timer',
#   'house',
#   'ridiculous'],
#  ['absolutely', 'garbage', 'way', 'lose', 'privacy'],
#  ['use',
#   'music',
#   'unplug',
#   'another',
#   'way',
#   'company',
#   'listen',
#   'steal',
#   'privacy'],
#  ['invaision', 'privacy'],
#  ['creepy', 'privacy', 'pirate'],
#  ['many',
#   'problem',
#   'issue',
#   'begin',
#   'warn',
#   'overpermissioned',
#   'app',
#   'major',
#   'permission',
#   'creep',
#   'update',
#   'anyone',
#   'concern',
#   'privacy',
#   'security',
#   'avoid',
#   'app',
#   'make',
#   'mistake',
#   'track',
#   'data',
#   'mining',
#   'spyware',
#   'also',
#   'app',
#   'act',
#   'like',
#   'virus',
#   'direct',
#   'easy',
#   'way',
#   'stopexit',
#   'app',
#   'keep',
#   'thing',
#   'run',
#   'run',
#   'background',
#   'eat',
#   'resource',
#   'battery',
#   'even',
#   'want',
#   'want',
#   'stop',
#   'major',
#   'usability',
#   'issue',
#   'app',
#   'unstable',
#   'constantly',
#   'hang',
#   'crash',
#   'especially',
#   'setup',
#   'mode',
#   'release',
#   'dangerous',
#   'unusable',
#   'amazon',
#   'control',
#   'megamonster',
#   'need',
#   'well'],
#  ['alexa', 'spy', 'danger', 'everyones', 'privicy', 'get', 'garbage'],
#  ['suck',
#   'app',
#   'really',
#   'suck',
#   'thing',
#   'take',
#   'space',
#   'phone',
#   'provide',
#   'designer',
#   'information',
#   'sell',
#   'without',
#   'permission',
#   'install',
#   'garbage'],
#  ['privacy', 'app', 'service', 'dangerously', 'poor', 'yes', 'dangerously'],
#  ['clearly',
#   'need',
#   'force',
#   'access',
#   'microphone',
#   'mobile',
#   'phone',
#   'use',
#   'app',
#   'setup',
#   'another',
#   'device',
#   'hate',
#   'type',
#   'needle',
#   'intrusive',
#   'access',
#   'want',
#   'use',
#   'alexa',
#   'phone',
#   'let',
#   'grant',
#   'permission',
#   'time',
#   'meanwhile',
#   'push',
#   'device',
#   'work',
#   'clunky',
#   'maze',
#   'option',
#   'moon',
#   'bezos'],
#  ['good', 'minus', 'privacy', 'issue'],
#  ['want',
#   'app',
#   'privacy',
#   'concern',
#   'give',
#   'kind',
#   'choice',
#   'would',
#   'download',
#   'it',
#   'amazon',
#   'bloatware',
#   'need',
#   'for',
#   'space',
#   'leave',
#   'kindle',
#   'fire',
#   'update',
#   'apps',
#   'actually',
#   'want',
#   'use',
#   'force',
#   'installation',
#   'alexa',
#   'make',
#   'kindle',
#   'fire',
#   'absolutely',
#   'useless',
#   'me',
#   'buy',
#   'another',
#   'amazon',
#   'tablet',
#   'due',
#   'ongoing',
#   'problem',
#   'ive',
#   'force',
#   'download',
#   'proprietary',
#   'software',
#   'need',
#   'prevent',
#   'thing',
#   'actually',
#   'want',
#   'need',
#   'tablet',
#   'for'],
#  ['last',
#   'day',
#   'keep',
#   'get',
#   'message',
#   'alexa',
#   'app',
#   'crash',
#   'problem',
#   'turn',
#   'app',
#   'get',
#   'annoying',
#   'actually',
#   'dangerous',
#   'im',
#   'use',
#   'navigation',
#   'app',
#   'drive',
#   'alexa',
#   'message',
#   'show',
#   'block',
#   'view',
#   'screen',
#   'cant',
#   'see',
#   'map',
#   'dismiss',
#   'thr',
#   'alexa',
#   'message',
#   'please',
#   'fix',
#   'asap'],
#  ['review',
#   'perspective',
#   'echo',
#   'auto',
#   'user',
#   'case',
#   'ever',
#   'use',
#   'app',
#   'alexa',
#   'app',
#   'atrocious',
#   'car',
#   'use',
#   'least',
#   'android',
#   'pie',
#   'could',
#   'distract',
#   'point',
#   'dangerous',
#   'constantly',
#   'want',
#   'top',
#   'everything',
#   'start',
#   'car',
#   'turn',
#   'waze',
#   'plug',
#   'destination',
#   'start',
#   'drive',
#   'look',
#   'screen',
#   'get',
#   'next',
#   'turn',
#   'info',
#   'instead',
#   'waze',
#   'see',
#   'alexa',
#   'screen',
#   'get',
#   'rid',
#   'screen',
#   'waze',
#   'back',
#   'up',
#   'ok',
#   'good',
#   'no',
#   'good',
#   'literally',
#   'second',
#   'late',
#   'alexa',
#   'app',
#   'screen',
#   'back',
#   'top',
#   'everything',
#   'cant',
#   'see',
#   'map',
#   'again',
#   'get',
#   'rid',
#   'alexa',
#   'screen',
#   'while',
#   'drive',
#   'light',
#   'mind',
#   'you',
#   'back',
#   'wanope',
#   'time',
#   'second',
#   'need',
#   'see',
#   'direction',
#   'beauty',
#   'cannot',
#   'exist',
#   'app',
#   'nope',
#   'give',
#   'alexa',
#   'permission',
#   'run',
#   'background',
#   'time',
#   'want',
#   'even',
#   'car',
#   'listen',
#   'constantly',
#   'even',
#   'need',
#   'suck',
#   'battery',
#   'dry',
#   'cant',
#   'kill',
#   'it',
#   'bad',
#   'app',
#   'behavior',
#   'thing',
#   'tell',
#   'install',
#   'if',
#   'want',
#   'disable',
#   'this',
#   'go',
#   'setting',
#   'blah',
#   'blah',
#   'blah',
#   'nope',
#   'cant',
#   'either',
#   'see',
#   'set',
#   'setting',
#   'grey',
#   'out',
#   'manage',
#   'live',
#   'it',
#   'need',
#   'want',
#   'app',
#   'run',
#   'home',
#   'already',
#   'firecube',
#   'dpt',
#   'show',
#   'listen',
#   'everything',
#   'go',
#   'house',
#   'give',
#   'app',
#   'permission',
#   'run',
#   'constantly',
#   'background',
#   'say',
#   'work',
#   'unless',
#   'allow',
#   'to',
#   'true',
#   'start',
#   'alexa',
#   'app',
#   'manually',
#   'app',
#   'tasker',
#   'set',
#   'detect',
#   'connect',
#   'car',
#   'via',
#   'bt',
#   'start',
#   'alexa',
#   'app',
#   'tasker',
#   'set',
#   'phone',
#   'disconnect',
#   'car',
#   'bt',
#   'kill',
#   'alexa',
#   'actually',
#   'successful',
#   'kill',
#   'alexa',
#   'time',
#   'app',
#   'instal',
#   'call',
#   'power',
#   'master',
#   'detect',
#   'powerhungry',
#   'apps',
#   'which',
#   'alexa',
#   'be',
#   'surprise',
#   'notify',
#   'notification',
#   'area',
#   'so',
#   'forget',
#   'allow',
#   'actually',
#   'kill',
#   'them',
#   'tasker',
#   'fail',
#   'kill',
#   'alexa',
#   'automatically',
#   'job',
#   'otherwise',
#   'way',
#   'kill',
#   'ridiculously',
#   'invasive',
#   'app',
#   'reboot',
#   'phone'],
#  ['make', 'charge', 'account', 'without', 'knowledge', 'delete', 'app'],
#  ['new',
#   'update',
#   'cant',
#   'access',
#   'unlimited',
#   'subscription',
#   'hate',
#   'it'],
#  ['average',
#   'nothing',
#   'noteworthy',
#   'here',
#   'beware',
#   'get',
#   'scammed',
#   'too'],
#  ['battery',
#   'usage',
#   'issue',
#   'samsung',
#   'mobile',
#   'skill',
#   'uk',
#   'market',
#   'be',
#   'far',
#   'between',
#   'voice',
#   'command',
#   'understand',
#   'command',
#   'next',
#   'time',
#   'understand',
#   'play',
#   'music',
#   'fairly',
#   'high',
#   'volume',
#   'hear',
#   'command',
#   'unless',
#   'shout',
#   'heyho',
#   'early',
#   'day',
#   'make',
#   'sure',
#   'say',
#   'correct',
#   'title',
#   'artist',
#   'ask',
#   'music',
#   'instance',
#   'sayplay',
#   'eagle',
#   'hotel',
#   'california',
#   'miss',
#   'the',
#   'find',
#   'it',
#   'least',
#   'yet',
#   'otherwise',
#   'good',
#   'kit',
#   'late',
#   'update',
#   'remove',
#   'personal',
#   'setting',
#   'icon',
#   'home',
#   'screen',
#   'wifi',
#   'reset',
#   'whole',
#   'interface',
#   'change',
#   'good',
#   'upgrade'],
#  ['eat',
#   'phone',
#   'battery',
#   'make',
#   'phone',
#   'good',
#   'hand',
#   'warm',
#   'bad',
#   'last',
#   'couple',
#   'hour',
#   'whatever',
#   'background',
#   'alexa',
#   'app',
#   'also',
#   'impact',
#   'phone',
#   'performance',
#   'cause',
#   'sluggish',
#   'lag',
#   'use',
#   'apps',
#   'force',
#   'uninstall',
#   'it'],
#  ['since',
#   'new',
#   'update',
#   'app',
#   'drain',
#   'phone',
#   'battery',
#   'charge',
#   'phone',
#   'multiple',
#   'time',
#   'every',
#   'day',
#   'disable',
#   'app',
#   'battery',
#   'back',
#   'last',
#   'day',
#   'please',
#   'fix',
#   'thank',
#   'you'],
#  ['app',
#   'report',
#   'phone',
#   'drain',
#   'battery',
#   'fast',
#   'restrict',
#   'every',
#   'day',
#   'lg',
#   'velvet',
#   'tmobile',
#   'thanks'],
#  ['cannot', 'access', 'account'],
#  ['want',
#   'complain',
#   'something',
#   'decide',
#   'change',
#   'name',
#   'legit',
#   'name',
#   'school',
#   'purpose',
#   'now',
#   'still',
#   'cant',
#   'access',
#   'account',
#   'ive',
#   'already',
#   'send',
#   'photo',
#   'id',
#   'happen',
#   'week',
#   'now',
#   'hope',
#   'take',
#   'action',
#   'towards',
#   'problem',
#   'soon',
#   'possible',
#   'please',
#   'need',
#   'account',
#   'school',
#   'thank',
#   'you'],
#  ['reason',
#   'like',
#   'facebook',
#   'right',
#   'yall',
#   'act',
#   'stupid',
#   'make',
#   'everybody',
#   'video',
#   'login',
#   'cant',
#   'put',
#   'picture',
#   'back',
#   'like',
#   'use',
#   'ive',
#   'try',
#   'get',
#   'facebook',
#   'week',
#   'ive',
#   'try',
#   'get',
#   'facebook',
#   'week',
#   'make',
#   'video',
#   'accept',
#   'picture',
#   'anymore',
#   'first',
#   'try',
#   'get',
#   'facebook',
#   'ive',
#   'account',
#   'facebook',
#   'year',
#   'im',
#   'upset',
#   'ive',
#   'already',
#   'two',
#   'account',
#   'ive',
#   'cancel',
#   'yall',
#   'job',
#   'make',
#   'sure',
#   'get',
#   'hack',
#   'ive',
#   'lose',
#   'picture',
#   'ive',
#   'lose',
#   'friend',
#   'ive',
#   'lose',
#   'everything',
#   'last',
#   'year',
#   'ive',
#   'lose',
#   'group',
#   'cant',
#   'even',
#   'become',
#   'ministrator',
#   'back',
#   'group',
#   'yall',
#   'let',
#   'old',
#   'account'],
#  ['good',
#   'make',
#   'several',
#   'hundred',
#   'password',
#   'screen',
#   'lock',
#   'photo',
#   'ect',
#   'different',
#   'account',
#   'th',
#   'one',
#   'cant',
#   'access',
#   'account',
#   'ereplacible',
#   'photo',
#   'kid',
#   'growng',
#   'mention',
#   'two',
#   'family',
#   'pet',
#   'deceased',
#   'countles',
#   'photo',
#   'vacation',
#   'friend',
#   'deceased',
#   'well',
#   'thanks',
#   'alot',
#   'limit',
#   'everything',
#   'android',
#   'device',
#   'google',
#   'face',
#   'book',
#   'apps',
#   'matter',
#   'fact',
#   'im',
#   'go',
#   'back',
#   'time',
#   'landline'],
#  ['cannot',
#   'access',
#   'page',
#   'ive',
#   'like',
#   'page',
#   'section',
#   'report',
#   'numerous',
#   'time',
#   'still',
#   'resolve'],
#  ['currently',
#   'unable',
#   'log',
#   'message',
#   'spam',
#   'send',
#   'account',
#   'try',
#   'everything',
#   'get',
#   'back',
#   'facebook',
#   'app',
#   'laptop',
#   'chromebook',
#   'luck',
#   'ask',
#   'confirm',
#   'recent',
#   'post',
#   'say',
#   'connection',
#   'lose',
#   'retry',
#   'get',
#   'blue',
#   'screen',
#   'try',
#   'via',
#   'online',
#   'browser',
#   'get',
#   'sorry',
#   'something',
#   'go',
#   'wrong',
#   'message',
#   'please',
#   'help',
#   'cannot',
#   'access',
#   'personal',
#   'page',
#   'business',
#   'page',
#   'messenger',
#   'go',
#   'lose',
#   'business'],
#  ['update',
#   'app',
#   'cant',
#   'access',
#   'business',
#   'page',
#   'spend',
#   'hour',
#   'phone',
#   'try',
#   'sort',
#   'cant',
#   'uninstall',
#   'anything',
#   'everytime',
#   'cause',
#   'issue',
#   'please',
#   'advise',
#   'asap',
#   'send',
#   'report',
#   'guess',
#   'wait',
#   'age',
#   'response'],
#  ['bad',
#   'customer',
#   'service',
#   'account',
#   'hack',
#   'disable',
#   'sine',
#   'day',
#   'dont',
#   'receive',
#   'support',
#   'fb'],
#  ['account',
#   'disable',
#   'facebook',
#   'almost',
#   'half',
#   'month',
#   'now',
#   'since',
#   'try',
#   'contact',
#   'every',
#   'whereplease',
#   'help'],
#  ['report',
#   'page',
#   'keep',
#   'reuploading',
#   'steal',
#   'content',
#   'give',
#   'proper',
#   'credit'],
#  ['cannot',
#   'access',
#   'marketplace',
#   'search',
#   'function',
#   'work',
#   'forward',
#   'feedback',
#   'several',
#   'time',
#   'reply',
#   'fix'],
#  ['deactivate',
#   'account',
#   'tell',
#   'why',
#   'every',
#   'time',
#   'go',
#   'help',
#   'center',
#   'try',
#   'review',
#   'why',
#   'say',
#   'connection',
#   'lose',
#   'connection',
#   'fine',
#   'hate',
#   'lose',
#   'account',
#   'lose',
#   'picture',
#   'family',
#   'nothing',
#   'wrong',
#   'sure',
#   'contact'],
#  ['report',
#   'persongroup',
#   'run',
#   'personal',
#   'lottery',
#   'tell',
#   'break',
#   'community',
#   'std',
#   'however',
#   'speak',
#   'gamble',
#   'commission',
#   'go',
#   'look',
#   'confirm',
#   'law'],
#  ['interest',
#   'eyeopener',
#   'lot',
#   'different',
#   'personality',
#   'group',
#   'group',
#   'addictive'],
#  ['terrible', 'censorship'],
#  ['negative', 'experience', 'facebook', 'totalitarianism', 'censorship'],
#  ['unlawful',
#   'break',
#   'st',
#   'american',
#   'amendment',
#   'freedom',
#   'speech',
#   'censor',
#   'represent',
#   'republican',
#   'party',
#   'meanwhile',
#   'allow',
#   'democratic',
#   'party',
#   'post',
#   'false',
#   'damage',
#   'report',
#   'either',
#   'american',
#   'president',
#   'supporter',
#   'democracy',
#   'law',
#   'breaker',
#   'amendment',
#   'right'],
#  ['much',
#   'push',
#   'project',
#   'president',
#   'fact',
#   'check',
#   'opinion',
#   'differ',
#   'lot',
#   'censoring',
#   'st',
#   'amendment',
#   'right',
#   'many',
#   'ridiculous',
#   'ad',
#   'anything',
#   'facebook',
#   'suppose',
#   'about',
#   'walk',
#   'car',
#   'lot',
#   'doea',
#   'mean',
#   'want',
#   'ad',
#   'car',
#   'place',
#   'pop',
#   'damn',
#   'facebook',
#   'fee'],
#  ['facebook',
#   'say',
#   'use',
#   'independent',
#   'nonpartisan',
#   'factcheckers',
#   'lie',
#   'use',
#   'nothing',
#   'bias',
#   'leave',
#   'wing',
#   'lie',
#   'factcheckers'],
#  ['sorry',
#   'experience',
#   'see',
#   'continuously',
#   'fact',
#   'check',
#   'thing',
#   'post',
#   'dont',
#   'like',
#   'fact',
#   'post',
#   'truth',
#   'doesnt',
#   'give',
#   'right',
#   'censor',
#   'post'],
#  ['much', 'censorship', 'fake'],
#  ['get', 'tire', 'scammer', 'get', 'rid'],
#  ['censor',
#   'everything',
#   'get',
#   'butt',
#   'hurt',
#   'small',
#   'post',
#   'even',
#   'defend',
#   'get',
#   'put',
#   'facebook',
#   'jail',
#   'bully'],
#  ['theyve',
#   'become',
#   'social',
#   'control',
#   'instead',
#   'social',
#   'medium',
#   'platform',
#   'fact',
#   'check',
#   'nothing',
#   'leave',
#   'lean',
#   'propaganda',
#   'im',
#   'adult',
#   'year',
#   'old',
#   'figure',
#   'thing',
#   'myself',
#   'without',
#   'propaganda'],
#  ['like', 'censor', 'right', 'free', 'speech', 'infringe', 'on'],
#  ['fake',
#   'fact',
#   'checker',
#   'engineer',
#   'society',
#   'google',
#   'twitter',
#   'start',
#   'cia',
#   'fbs',
#   'time',
#   'over'],
#  ['censorship',
#   'suck',
#   'political',
#   'correctness',
#   'suck',
#   'facebook',
#   'much',
#   'business',
#   'regulate',
#   'free',
#   'speech',
#   'promote',
#   'leftist',
#   'politics'],
#  ['tire', 'sensoring', 'instead', 'allow', 'people', 'make', 'decision'],
#  ['pathetically',
#   'bias',
#   'information',
#   'suppress',
#   'delete',
#   'account',
#   'go',
#   'elsewhere',
#   'lot',
#   'friend',
#   'family',
#   'too',
#   'one',
#   'star',
#   'way',
#   'much',
#   'platform',
#   'hope',
#   'pray',
#   'everyday',
#   'mark',
#   'zuckerberg',
#   'go',
#   'prison',
#   'account',
#   'influence',
#   'election',
#   'result',
#   'among',
#   'thing',
#   'well'],
#  ['much', 'censorship'],
#  ['many', 'right', 'violation', 'form', 'censorship', 'disguise', 'guideline'],
#  ['im',
#   'tire',
#   'restriction',
#   'censoring',
#   'especially',
#   'election',
#   'invade',
#   'privacy',
#   'strip',
#   'right',
#   'free',
#   'speech',
#   'im',
#   'tire',
#   'it',
#   'thats',
#   'many',
#   'leave',
#   'platform',
#   'control',
#   'right',
#   'violate',
#   'post',
#   'lie',
#   'democrat',
#   'liberal',
#   'medium',
#   'delete',
#   'post',
#   'put',
#   'support',
#   'conservative',
#   'sick',
#   'it',
#   'social',
#   'medium',
#   'platform',
#   'isnt',
#   'worth',
#   'keep',
#   'anymore',
#   'people',
#   'leave'],
#  ['way',
#   'much',
#   'censoring',
#   'speak',
#   'about',
#   'cartoon',
#   'opinion',
#   'support',
#   'use',
#   'really',
#   'enjoy',
#   'get',
#   'political',
#   'america'],
#  ['give',
#   'one',
#   'star',
#   'to',
#   'tire',
#   'political',
#   'game',
#   'independent',
#   'fact',
#   'checker',
#   'allow',
#   'publish',
#   'thing',
#   'fit',
#   'agenda',
#   'obviously',
#   'facebook',
#   'forget',
#   'start',
#   'stand',
#   'for'],
#  ['censor'],
#  ['cencorship',
#   'control',
#   'quality',
#   'fine',
#   'communist',
#   'control',
#   'company'],
#  ['sick', 'tire', 'censorship', 'retoric'],
#  ['app',
#   'use',
#   'fun',
#   'cant',
#   'post',
#   'anything',
#   'without',
#   'censor',
#   'fact',
#   'check',
#   'post',
#   'fact',
#   'get',
#   'check',
#   'cant',
#   'prove',
#   'factual',
#   'become',
#   'network',
#   'political',
#   'bias',
#   'amd',
#   'anthing',
#   'go',
#   'belief',
#   'get',
#   'shut',
#   'down',
#   'completly',
#   'ignore',
#   'free',
#   'speech',
#   'go',
#   'well',
#   'app',
#   'call',
#   'mewe',
#   'post',
#   'anything',
#   'want',
#   'long',
#   'porn',
#   'bully',
#   'facebook',
#   'become',
#   'radical',
#   'joke'],
#  ['bias',
#   'censorship',
#   'plus',
#   'want',
#   'track',
#   'every',
#   'move',
#   'facebook',
#   'get',
#   'enable',
#   'device',
#   'change',
#   'bad',
#   'behaviour'],
#  ['trust', 'app', 'evasive', 'riddle', 'liberal', 'censorship'],
#  ['attribute',
#   'customer',
#   'facebookand',
#   'spend',
#   'boost',
#   'advertising',
#   'more',
#   'people',
#   'drop',
#   'facebook',
#   'messenger',
#   'huge',
#   'privacy',
#   'concern',
#   'facebook',
#   'monitor',
#   'gps',
#   'create',
#   'data',
#   'base',
#   'profile',
#   'user',
#   'nsa',
#   'censorship',
#   'shadow',
#   'ban'],
#  ['take', 'away', 'freedom', 'speech'],
#  ['facebook',
#   'become',
#   'bad',
#   'everyday',
#   'like',
#   'want',
#   'censorship',
#   'time',
#   'move',
#   'different',
#   'platform',
#   'avoid',
#   'big',
#   'tech',
#   'company',
#   'like',
#   'facebook',
#   'good',
#   'brainwash',
#   'idiot'],
#  ['censor', 'political', 'wrongness'],
#  ['amaze',
#   'connect',
#   'old',
#   'friend',
#   'especially',
#   'share',
#   'political',
#   'opinion',
#   'zuck',
#   'ban'],
#  ['much', 'censorship'],
#  ['tag',
#   'video',
#   'picture',
#   'kill',
#   'nigeria',
#   'false',
#   'information',
#   'guy',
#   'big',
#   'disgrace'],
#  ['never',
#   'year',
#   'use',
#   'app',
#   'disgust',
#   'now',
#   'blatant',
#   'lie',
#   'lack',
#   'free',
#   'speech',
#   'practice',
#   'sister',
#   'get',
#   'ban',
#   'joke',
#   'me',
#   'get',
#   'together',
#   'idiot'],
#  ['good',
#   'site',
#   'freedom',
#   'speech',
#   'fake',
#   'fact',
#   'checker',
#   'lot',
#   'censorship'],
#  ['facebook',
#   'become',
#   'control',
#   'post',
#   'censor',
#   'christian',
#   'value',
#   'allow',
#   'immoral',
#   'pedophilia',
#   'page'],
#  ['much', 'censoring'],
#  ['learn',
#   'face',
#   'book',
#   'group',
#   'page',
#   'block',
#   'part',
#   'ongoing',
#   'farmer',
#   'strike',
#   'india',
#   'mr',
#   'zuckerberg',
#   'ashamed',
#   'lick',
#   'modis',
#   'shoe'],
#  ['much', 'censorship', 'fact', 'check', 'b'],
#  ['like', 'one', 'side', 'censorship'],
#  ['facebook',
#   'long',
#   'social',
#   'platform',
#   'free',
#   'speech',
#   'free',
#   'think',
#   'fb',
#   'another',
#   'corrupt',
#   'arm',
#   'socialist',
#   'leave',
#   'drop',
#   'fb',
#   'head',
#   'mewe',
#   'enjoy',
#   'uncensored',
#   'free',
#   'speech',
#   'bye',
#   'zuck'],
#  ['fact',
#   'checker',
#   'fact',
#   'check',
#   'conservative',
#   'agree',
#   'agenda',
#   'mean',
#   'wrong',
#   'live',
#   'america',
#   'country',
#   'build',
#   'freedom',
#   'include',
#   'freedom',
#   'speech',
#   'get',
#   'rid',
#   'fact',
#   'checker',
#   'also',
#   'medium',
#   'get',
#   'call',
#   'election',
#   'neither',
#   'facebook',
#   'take',
#   'box',
#   'inform',
#   'u',
#   'election',
#   'call',
#   'biden'],
#  ['wish',
#   'could',
#   'give',
#   'rampant',
#   'censorship',
#   'violation',
#   'free',
#   'speech',
#   'right',
#   'sell',
#   'personal',
#   'info',
#   'spy',
#   'propaganda',
#   'intimidationpenalization',
#   'view',
#   'rabidly',
#   'liberal',
#   'target',
#   'solicitation',
#   'advertisingmake',
#   'facebook',
#   'horrible',
#   'social',
#   'medium',
#   'platform',
#   'use',
#   'mewe',
#   'instead'],
#  ['hate', 'censorshipmewe', 'well', 'censorship'],
#  ['suck',
#   'zuckerberg',
#   'call',
#   'factcheckers',
#   'censorship',
#   'way',
#   'run',
#   'business'],
#  ['facebook',
#   'use',
#   'fun',
#   'friendly',
#   'place',
#   'web',
#   'theyre',
#   'try',
#   'take',
#   'away',
#   'true',
#   'freedom',
#   'speech',
#   'opinion'],
#  ['bias',
#   'liar',
#   'censor',
#   'conservative',
#   'yet',
#   'allow',
#   'absolutely',
#   'anything',
#   'corrupt',
#   'leave',
#   'democrat'],
#  ['much', 'censorship'],
#  ['facebook',
#   'see',
#   'authority',
#   'censoring',
#   'truth',
#   'anything',
#   'agree',
#   'lefty',
#   'wake',
#   'agenda',
#   'constantly',
#   'reduce',
#   'user',
#   'privacy',
#   'time',
#   'delete',
#   'facebook',
#   'think'],
#  ['use',
#   'great',
#   'gestapo',
#   'zuckerberg',
#   'become',
#   'big',
#   'fan',
#   'censorship'],
#  ['censorship', 'beyond', 'disgust'],
#  ['fakebook',
#   'get',
#   'much',
#   'like',
#   'nazi',
#   'be',
#   'america',
#   'free',
#   'speech',
#   'zone',
#   'stop',
#   'censoring',
#   'people',
#   'speech'],
#  ['free', 'speech'],
#  ['shut',
#   'censor',
#   'app',
#   'align',
#   'think',
#   'opinion',
#   'belief',
#   'also',
#   'call',
#   'fact',
#   'checker',
#   'bogus',
#   'know',
#   'truth',
#   'sit',
#   'face',
#   'steer',
#   'clear',
#   'go',
#   'mewe',
#   'parler',
#   'censorship',
#   'platform'],
#  ['appreciate', 'censorship', 'conservative', 'topic'],
#  ['poor',
#   'like',
#   'force',
#   'feed',
#   'information',
#   'first',
#   'amendment',
#   'right',
#   'trample',
#   'on',
#   'regardless',
#   'opinion',
#   'entitle',
#   'them',
#   'affiliate',
#   'political',
#   'party',
#   'still',
#   'believe',
#   'right'],
#  ['unbelieveable', 'crappy', 'sensor', 'like', 'only'],
#  ['censorship', 'horrible'],
#  ['censorship',
#   'bull',
#   'bias',
#   'anti',
#   'trump',
#   'bull',
#   'see',
#   'friend',
#   'post',
#   'bull',
#   'bias',
#   'censorship',
#   'thats',
#   'really',
#   'horrible'],
#  ['great',
#   'like',
#   'censorship',
#   'worst',
#   'next',
#   'twitter',
#   'want',
#   'share',
#   'information',
#   'theyll',
#   'block',
#   'truth',
#   'sure'],
#  ['violate', 'free', 'speech'],
#  ['delete',
#   'due',
#   'support',
#   'jo',
#   'jorgensen',
#   'long',
#   'support',
#   'company',
#   'violate',
#   'free',
#   'speech'],
#  ['facebook', 'allow', 'freedom', 'speech'],
#  ['censorship',
#   'beyond',
#   'measure',
#   'fact',
#   'check',
#   'article',
#   'article',
#   'trump',
#   'conservative',
#   'bannedblocked',
#   'time',
#   'period',
#   'post',
#   'negative',
#   'biden',
#   'lock',
#   'state',
#   'opinion',
#   'fact',
#   'checker',
#   'allow',
#   'hate',
#   'post',
#   'long',
#   'president',
#   'country',
#   'would',
#   'give',
#   'fb',
#   'negative',
#   'option'],
#  ['terrible', 'app', 'free', 'speech', 'censorship', 'control'],
#  ['application',
#   'propagate',
#   'radical',
#   'ideology',
#   'suppress',
#   'openmindedness',
#   'conservative',
#   'view',
#   'would',
#   'recommend',
#   'worst',
#   'enemy',
#   'want',
#   'child',
#   'brainwash',
#   'feel',
#   'free',
#   'let',
#   'use',
#   'app',
#   'cannot',
#   'express',
#   'much',
#   'censorship',
#   'illegal',
#   'observe',
#   'platform'],
#  ['stop', 'censorship'],
#  ['sure',
#   'think',
#   'give',
#   'power',
#   'regulate',
#   'free',
#   'speech',
#   'everyone',
#   'country',
#   'guarantee',
#   'constitution',
#   'hopefully',
#   'remove',
#   'protection',
#   'start',
#   'pay',
#   'people',
#   'choice',
#   'figure',
#   'out',
#   'always',
#   'good',
#   'money',
#   'come',
#   'hopefully',
#   'soon',
#   'realize',
#   'feel',
#   'go',
#   'way',
#   'bos',
#   'regulator',
#   'one'],
#  ['attempt',
#   'censor',
#   'fail',
#   'nothing',
#   'stop',
#   'whats',
#   'come',
#   'welcome',
#   'great',
#   'awaken'],
#  ['censorship',
#   'horrible',
#   'push',
#   'agenda',
#   'take',
#   'freedom',
#   'speech',
#   'away',
#   'delete',
#   'account'],
#  ['use',
#   'like',
#   'facebook',
#   'im',
#   'tire',
#   'censor',
#   'bc',
#   'im',
#   'biden',
#   'fan',
#   'ridiculous',
#   'shadow',
#   'bann',
#   'people',
#   'bc',
#   'opposite',
#   'view',
#   'you',
#   'care',
#   'much',
#   'money',
#   'have',
#   'disgust'],
#  ['joke',
#   'cant',
#   'say',
#   'anything',
#   'without',
#   'someone',
#   'get',
#   'offend',
#   'call',
#   'person',
#   'cracker',
#   'get',
#   'block',
#   'day',
#   'call',
#   'n',
#   'word',
#   'nothing',
#   'happen',
#   'them',
#   'ur',
#   'joke',
#   'fb',
#   'pretty',
#   'much',
#   'communist',
#   'site',
#   'control',
#   'everything',
#   'post',
#   'bad',
#   'china',
#   'could',
#   'give',
#   'zero',
#   'star',
#   'would',
#   'try',
#   'share',
#   'free',
#   'thanksgiving',
#   'dinner',
#   'needy',
#   'homeless',
#   'get',
#   'block',
#   'ridiculous',
#   'mark',
#   'suckerberg',
#   'shame',
#   'ban',
#   'certain',
#   'people',
#   'comment'],
#  ['app',
#   'good',
#   'but',
#   'app',
#   'fake',
#   'news',
#   'stop',
#   'fake',
#   'news',
#   'popular',
#   'app',
#   'early'],
#  ['great',
#   'app',
#   'liberal',
#   'factcheckers',
#   'try',
#   'silence',
#   'anyone',
#   'different',
#   'opinion',
#   'delete',
#   'soon'],
#  ['support',
#   'constitutional',
#   'right',
#   'free',
#   'speech',
#   'sensor',
#   'conservative',
#   'view',
#   'push',
#   'socialist',
#   'agenda'],
#  ['dislike',
#   'censoring',
#   'call',
#   'fact',
#   'check',
#   'progessive',
#   'political',
#   'belief',
#   'support',
#   'socialist',
#   'cause',
#   'suppression',
#   'conservative',
#   'speech',
#   'issue',
#   'obvious'],
#  ['censorship', 'free', 'speech', 'repulsive', 'constitution'],
#  ['bias', 'inhibit', 'freedom', 'expression'],
#  ['friend',
#   'comment',
#   'often',
#   'regularly',
#   'censor',
#   'indoctrinate',
#   'cannot',
#   'believe'],
#  ['censorship',
#   'conservative',
#   'post',
#   'people',
#   'capable',
#   'make',
#   'mind',
#   'need',
#   'want',
#   'opinion',
#   'facebook',
#   'fact',
#   'checker'],
#  ['facebook',
#   'liberal',
#   'sitethat',
#   'censor',
#   'people',
#   'voicesand',
#   'ban',
#   'anyone',
#   'speak',
#   'ill',
#   'leave',
#   'download',
#   'mewe'],
#  ['use', 'fun', 'fact', 'check', 'start'],
#  ['like', 'censor'],
#  ['censor', 'everything', 'conservative'],
#  ['work',
#   'enemy',
#   'think',
#   'police',
#   'cckscker',
#   'control',
#   'power',
#   'outside',
#   'republic',
#   'make',
#   'it'],
#  ['facebook',
#   'bias',
#   'corrupt',
#   'conservative',
#   'republican',
#   'let',
#   'talk',
#   'people',
#   'control',
#   'right',
#   'wrong',
#   'send',
#   'message',
#   'facebook'],
#  ['app',
#   'good',
#   'overall',
#   'great',
#   'keep',
#   'touch',
#   'family',
#   'friend',
#   'previously',
#   'rat',
#   'app',
#   'star',
#   'however',
#   'become',
#   'overly',
#   'censor',
#   'perpetuate',
#   'post',
#   'support',
#   'belief',
#   'view',
#   'opinion',
#   'others',
#   'get',
#   'delete'],
#  ['much', 'censorship'],
#  ['censor',
#   'information',
#   'even',
#   'middle',
#   'event',
#   'anything',
#   'discredit',
#   'mainstream',
#   'medium',
#   'shut',
#   'down',
#   'im',
#   'ready',
#   'leave',
#   'many',
#   'friend'],
#  ['f',
#   'u',
#   'facebook',
#   'hate',
#   'censorship',
#   'bullish',
#   'fact',
#   'check',
#   'delete',
#   'people',
#   'speak',
#   'truth',
#   'spend',
#   'time',
#   'money',
#   'scam',
#   'artist',
#   'instead',
#   'patriot'],
#  ['rediculous',
#   'amount',
#   'ad',
#   'many',
#   'observe',
#   'scamsknock',
#   'off',
#   'actual',
#   'artist',
#   'work',
#   'sad',
#   'pathetic',
#   'also',
#   'censorship',
#   'political',
#   'bias',
#   'absurd',
#   'look',
#   'platform',
#   'allow',
#   'freedom',
#   'speech',
#   'apparently',
#   'app',
#   'choose',
#   'also',
#   'resolution',
#   'terrible',
#   'try',
#   'upload',
#   'video',
#   'always',
#   'seem',
#   'look',
#   'well',
#   'instagram',
#   'whatever',
#   'reason'],
#  ['leave',
#   'side',
#   'liberal',
#   'shut',
#   'conservative',
#   'voice',
#   'claim',
#   'fact',
#   'check',
#   'credit',
#   'leave',
#   'apparently',
#   'people',
#   'believe',
#   'leave',
#   'medium',
#   'work',
#   'you'],
#  ['censoring',
#   'important',
#   'content',
#   'shadowbanning',
#   'function',
#   'dont',
#   'work',
#   'properly',
#   'cannot',
#   'access',
#   'inbox',
#   'app',
#   'cannot',
#   'join',
#   'facebook',
#   'group',
#   'get',
#   'hit',
#   'loading',
#   'error',
#   'post',
#   'good',
#   'enough',
#   'fix',
#   'issue',
#   'parler',
#   'way',
#   'functional',
#   'respectful',
#   'user',
#   'im',
#   'switch',
#   'parler',
#   'star',
#   'absolutely',
#   'useless',
#   'app',
#   'platform'],
#  ['cannot',
#   'access',
#   'picture',
#   'within',
#   'new',
#   'update',
#   'terrible',
#   'censorship',
#   'many',
#   'requirement',
#   'track',
#   'access'],
#  ['silence',
#   'free',
#   'speech',
#   'influence',
#   'election',
#   'fake',
#   'fact',
#   'chects',
#   'put',
#   'people',
#   'fb',
#   'jail',
#   'good',
#   'reason',
#   'claim',
#   'post',
#   'violate',
#   'community',
#   'standard',
#   'nudity',
#   'sexual',
#   'content',
#   'political',
#   'post',
#   'show',
#   'nothing',
#   'kind',
#   'silence',
#   'people',
#   'whatever',
#   'want',
#   'whatever',
#   'reason',
#   'lot',
#   'make',
#   'up',
#   'use',
#   'great',
#   'app',
#   'get',
#   'political',
#   'start',
#   'act',
#   'like',
#   'bunch',
#   'communist'],
#  ['censorship',
#   'fine',
#   'zuckerberg',
#   'delete',
#   'comment',
#   'disagree',
#   'political',
#   'stance',
#   'account',
#   'restrict',
#   'post',
#   'picture',
#   'man',
#   'shirt',
#   'open',
#   'determine',
#   'nudity',
#   'community',
#   'standard',
#   'way',
#   'challenge',
#   'decision',
#   'phone',
#   'look',
#   'alternative',
#   'social',
#   'medium',
#   'like',
#   'wimkin',
#   'mewe',
#   'censor',
#   'view'],
#  ['facebook',
#   'big',
#   'fraud',
#   'earth',
#   'use',
#   'information',
#   'keep',
#   'censoring',
#   'post',
#   'tell',
#   'truth',
#   'hide',
#   'truth',
#   'covid',
#   'big',
#   'scam',
#   'devil',
#   'work',
#   'hope',
#   'facebook',
#   'social',
#   'medium',
#   'burn',
#   'hell'],
#  ['liberal',
#   'propaganda',
#   'encourage',
#   'platform',
#   'truth',
#   'suppress',
#   'app',
#   'take',
#   'election',
#   'fraud'],
#  ['bully',
#   'bc',
#   'im',
#   'fat',
#   'im',
#   'gonna',
#   'get',
#   'facebook',
#   'cancellednobody',
#   'accept',
#   'me'],
#  ['post',
#   'communal',
#   'hatred',
#   'regularly',
#   'appear',
#   'facebook',
#   'wall',
#   'even',
#   'post',
#   'people',
#   'friend',
#   'list',
#   'page',
#   'like',
#   'spring',
#   'wall',
#   'random',
#   'hateful',
#   'post',
#   'clearly',
#   'contradict',
#   'declare',
#   'policy',
#   'facebook',
#   'unfortunately',
#   'reason',
#   'unknown',
#   'facebook',
#   'allow',
#   'this',
#   'certainly',
#   'turn',
#   'social',
#   'medium',
#   'like',
#   'facebook',
#   'antisocial',
#   'one',
#   'please',
#   'look',
#   'it'],
#  ['need',
#   'make',
#   'major',
#   'change',
#   'say',
#   'bully',
#   'standard',
#   'allow',
#   'bully',
#   'u',
#   'try',
#   'defend',
#   'bully',
#   'report',
#   'comment',
#   'get',
#   'put',
#   'facebook',
#   'jail',
#   'report',
#   'comment',
#   'nothing',
#   'about',
#   'give',
#   'u',
#   'option',
#   'make',
#   'ur',
#   'name',
#   'unsearchable',
#   'harrassed',
#   'matter',
#   'many',
#   'time',
#   'change',
#   'name',
#   'still',
#   'find',
#   'you',
#   'ive',
#   'contact',
#   'support',
#   'help',
#   'all',
#   'go',
#   'lose',
#   'alot',
#   'member',
#   'soon'],
#  ['stupid',
#   'as',
#   'white',
#   'boy',
#   'reference',
#   'quote',
#   'say',
#   'film',
#   'call',
#   'gladiator',
#   'white',
#   'guyin',
#   'black',
#   'town',
#   'boxingi',
#   'quote',
#   'film',
#   'call',
#   'gladiator',
#   'immediately',
#   'penialised',
#   'thisi',
#   'quote',
#   'video',
#   'young',
#   'adult',
#   'take',
#   'mick',
#   'handicappedmental',
#   'health',
#   'facebook',
#   'bull',
#   'mefacebook',
#   'wont',
#   'leave',
#   'alonewoman',
#   'opressed',
#   'fbfacebook',
#   'takenmy',
#   'human',
#   'right',
#   'free',
#   'speechididntmean',
#   'offenceienglishcaucasion'],
#  ['horrible',
#   'bias',
#   'toxic',
#   'despise',
#   'society',
#   'reliance',
#   'platform',
#   'factually',
#   'prove',
#   'awful',
#   'individual',
#   'society',
#   'hate',
#   'im',
#   'force',
#   'use',
#   'interact',
#   'rest',
#   'society',
#   'good',
#   'local',
#   'music',
#   'artist',
#   'spread',
#   'creativity',
#   'get',
#   'exposure',
#   'thats',
#   'literally',
#   'value',
#   'stupid',
#   'platform',
#   'have',
#   'would',
#   'give',
#   'negative',
#   'star',
#   'could'],
#  ['stope',
#   'islamophobia',
#   'community',
#   'guideline',
#   'khadim',
#   'hussain',
#   'razvi'],
#  ['freedom',
#   'speech',
#   'pretty',
#   'big',
#   'country',
#   'discrimination',
#   'to',
#   'problem',
#   'parler'],
#  ['stop', 'islamophubia', 'community', 'guideline', 'khadimhussainrizvi'],
#  ['stop', 'islamophobia', 'khadim', 'hussain', 'rizvi', 'zindabad'],
#  ['horrid',
#   'system',
#   'racist',
#   'discriminatory',
#   'anti',
#   'american',
#   'oppose',
#   'political',
#   'view',
#   'suppress',
#   'user',
#   'throw',
#   'jail',
#   'political',
#   'prisoner',
#   'ap',
#   'ban'],
#  ['bias', 'discriminatory'],
#  ['racist',
#   'black',
#   'brown',
#   'conservative',
#   'independent',
#   'leave',
#   'allow',
#   'threaten',
#   'harass',
#   'poc',
#   'well',
#   'white',
#   'different',
#   'opinion',
#   'post',
#   'comment',
#   'censor',
#   'non',
#   'violation',
#   'yet',
#   'animal',
#   'abuse',
#   'child',
#   'porn',
#   'allow',
#   'tell',
#   'exactly',
#   'leave',
#   'about'],
#  ['worst', 'medium', 'allow', 'islamic', 'speech', 'fb'],
#  ['block',
#   'everyone',
#   'disagree',
#   'elite',
#   'version',
#   'pandemic',
#   'promote',
#   'vaccine',
#   'killer',
#   'people',
#   'discredit',
#   'medicine',
#   'alternative'],
#  ['facebook',
#   'target',
#   'queer',
#   'people',
#   'artist',
#   'specifically',
#   'give',
#   'hard',
#   'time',
#   'name',
#   'policy',
#   'versuses',
#   'ci',
#   'people',
#   'ci',
#   'business',
#   'account',
#   'extremely',
#   'transphobic',
#   'discriminatory'],
#  ['love',
#   'need',
#   'protect',
#   'american',
#   'people',
#   'use',
#   'social',
#   'medium',
#   'reach',
#   'family',
#   'friend',
#   'work',
#   'ect',
#   'lot',
#   'fake',
#   'job',
#   'advertisement',
#   'facebook',
#   'use',
#   'facebook',
#   'steal',
#   'valuable',
#   'information',
#   'american',
#   'people',
#   'use',
#   'facebook',
#   'stop',
#   'con',
#   'artist'],
#  ['many', 'advertising', 'gamble', 'direct', 'kid'],
#  ['cant',
#   'something',
#   'online',
#   'gamble',
#   'ad',
#   'annoying',
#   'make',
#   'app',
#   'look',
#   'like',
#   'garbage',
#   'can'],
#  ['extremely',
#   'low',
#   'quality',
#   'ad',
#   'promote',
#   'prostitution',
#   'gamble',
#   'illegal',
#   'drug',
#   'useless',
#   'target',
#   'group',
#   'person',
#   'receive',
#   'category',
#   'fb',
#   'ad',
#   'income',
#   'xare',
#   'content',
#   'ad'],
#  ['hard',
#   'open',
#   'search',
#   'people',
#   'option',
#   'nudity',
#   'content',
#   'ad',
#   'post'],
#  ['someone',
#   'picture',
#   'husband',
#   'kid',
#   'page',
#   'say',
#   'relationship',
#   'report',
#   'literally',
#   'give',
#   'opportunity',
#   'either',
#   'block',
#   'unfriend',
#   'them',
#   'wasnt',
#   'anything',
#   'wrong',
#   'person',
#   'page',
#   'follow',
#   'rule'],
#  ['lose',
#   'personal',
#   'information',
#   'fight',
#   'almost',
#   'year',
#   'identity',
#   'theft',
#   'would',
#   'delete',
#   'fakebook',
#   'could',
#   'invedtigation',
#   'social',
#   'medium',
#   'sit',
#   'immediatly'],
#  ['love',
#   'able',
#   'connect',
#   'gigantic',
#   'family',
#   'usa',
#   'problem',
#   'catfishing',
#   'stalk',
#   'xmanager',
#   'xtenant',
#   'old',
#   'apts',
#   'still',
#   'still',
#   'many',
#   'trammitizing',
#   'isscues',
#   'make',
#   'family',
#   'friend',
#   'enemy',
#   'profile',
#   'photo',
#   'account',
#   'profile',
#   'photo',
#   'even',
#   'stalk',
#   'grandchild',
#   'facebook',
#   'account',
#   'back',
#   'back',
#   'steal',
#   'money',
#   'order',
#   'thing',
#   'internet',
#   'steal',
#   'family',
#   'friend',
#   'identity',
#   'plumishionen',
#   'clone',
#   'spam'],
#  ['ok',
#   'look',
#   'find',
#   'new',
#   'friend',
#   'old',
#   'one',
#   'family',
#   'member',
#   'way',
#   'world',
#   'go',
#   'cell',
#   'hack',
#   'time',
#   'guy',
#   'name',
#   'there',
#   'try',
#   'get',
#   'identity',
#   'theft',
#   'leave',
#   'hang',
#   'canada',
#   'ghost',
#   'computer',
#   'cant',
#   'even',
#   'file',
#   'income',
#   'tax',
#   'lol',
#   'well',
#   'suck',
#   'cause',
#   'steal',
#   'everything',
#   'idiot',
#   'man',
#   'take',
#   'ex',
#   'take',
#   'plate',
#   'gutless',
#   'loosers',
#   'lol'],
#  ['need',
#   'tighten',
#   'safety',
#   'privacy',
#   'boundary',
#   'average',
#   'consumerprevent',
#   'identity',
#   'theft',
#   'unscrupolous',
#   'individual',
#   'show',
#   'facebook',
#   'contact',
#   'stealung',
#   'private',
#   'photo',
#   'never',
#   'give',
#   'phone',
#   'no',
#   'ii',
#   'qyestionable',
#   'dubious',
#   'character',
#   'use',
#   'track',
#   'you',
#   'obtain',
#   'information',
#   'blackmail',
#   'steal',
#   'file',
#   'facebook',
#   'user',
#   'need',
#   'ii',
#   'place',
#   'sign',
#   'public',
#   'private',
#   'wth',
#   'specific',
#   'friend',
#   'hacker',
#   'beware',
#   'outsider',
#   'stop'],
#  ['great',
#   'way',
#   'voice',
#   'opinion',
#   'connect',
#   'friend',
#   'family',
#   'etc',
#   'leader',
#   'among',
#   'many',
#   'make',
#   'identity',
#   'theft',
#   'threat',
#   'seace',
#   'exist',
#   'know',
#   'id'],
#  ['great',
#   'way',
#   'connect',
#   'friend',
#   'also',
#   'open',
#   'door',
#   'identity',
#   'theft'],
#  ['much', 'catfishers'],
#  ['facebook',
#   'great',
#   'app',
#   'have',
#   'keep',
#   'wit',
#   'family',
#   'close',
#   'friend',
#   'matter',
#   'world',
#   'also',
#   'gift',
#   'curse',
#   'cause',
#   'abuse',
#   'catfished',
#   'hacker',
#   'etc',
#   'overall',
#   'carefull',
#   'choose',
#   'friend',
#   'protect',
#   'ur',
#   'account'],
#  ['facebook',
#   'allow',
#   'u',
#   'see',
#   'someone',
#   'want',
#   'friend',
#   'u',
#   'like',
#   'comment',
#   'interest',
#   'belief',
#   'kind',
#   'comment',
#   'would',
#   'help',
#   'u',
#   'make',
#   'decision',
#   'allow',
#   'life',
#   'even',
#   'facebook',
#   'much',
#   'go',
#   'identity',
#   'theft',
#   'people',
#   'world',
#   'try',
#   'start',
#   'relationship',
#   'friendship',
#   'give',
#   'sad',
#   'story',
#   'whats',
#   'go',
#   'want',
#   'send',
#   'money',
#   'road',
#   'less',
#   'help',
#   'stop',
#   'type',
#   'abuse'],
#  ['censorship', 'identity', 'theftlike', 'behavior'],
#  ['app',
#   'garbage',
#   'own',
#   'socialist',
#   'party',
#   'massive',
#   'spy',
#   'wear',
#   'commit',
#   'identity',
#   'theft',
#   'run',
#   'family',
#   'debt',
#   'illegal',
#   'steal',
#   'bank',
#   'card',
#   'information'],
#  ['identity', 'theft', 'censorship'],
#  ['one',
#   'worst',
#   'apps',
#   'ever',
#   'major',
#   'privacy',
#   'concern',
#   'identity',
#   'theft',
#   'large',
#   'size',
#   'many',
#   'permission',
#   'lie',
#   'label',
#   'thing',
#   'prove',
#   'fact',
#   'stats',
#   'false',
#   'news',
#   'censor',
#   'people',
#   'difference',
#   'opinion',
#   'dont',
#   'look',
#   'like',
#   'them',
#   'facebook',
#   'dirty',
#   'racist',
#   'company',
#   'ban',
#   'people',
#   'legitimacy',
#   'promote',
#   'communism',
#   'falicies'],
#  ['trouble',
#   'wit',
#   'catfishing',
#   'go',
#   'on',
#   'howevr',
#   'enjoy',
#   'facebook',
#   'whole',
#   'lot'],
#  ['pandora',
#   'old',
#   'radio',
#   'station',
#   'blue',
#   'southern',
#   'soul',
#   'pandorai',
#   'know',
#   'much',
#   'catfished',
#   'everything',
#   'take',
#   'away',
#   'radio',
#   'station',
#   'southern',
#   'soul',
#   'blue'],
#  ['facebook', 'bias', 'leader', 'identity', 'theft'],
#  ['think',
#   'app',
#   'outdated',
#   'like',
#   'government',
#   'operate',
#   'also',
#   'always',
#   'mess',
#   'use',
#   'catfishing',
#   'illegal',
#   'stuff'],
#  ['many',
#   'dummy',
#   'fake',
#   'account',
#   'hope',
#   'facebook',
#   'face',
#   'verification',
#   'security',
#   'measure',
#   'let',
#   'user',
#   'create',
#   'account',
#   'surely',
#   'help',
#   'combat',
#   'fake',
#   'news',
#   'identity',
#   'theft',
#   'hope',
#   'also',
#   'feature',
#   'like',
#   'easily',
#   'see',
#   'find',
#   'someone',
#   'use',
#   'photo',
#   'without',
#   'consent',
#   'challenge',
#   'probably',
#   'give',
#   'star'],
#  ['awesome',
#   'site',
#   'world',
#   'class',
#   'sure',
#   'love',
#   'kool',
#   'people',
#   'use',
#   'must',
#   'cyber',
#   'date',
#   'world',
#   'always',
#   'find',
#   'date',
#   'know',
#   'catfished',
#   'walk',
#   'beautiful',
#   'supermodel',
#   'model',
#   'ship',
#   'nobody',
#   'quite',
#   'sure',
#   'luck',
#   'drive',
#   'guess'],
#  ['would',
#   'like',
#   'able',
#   'describe',
#   'report',
#   'detail',
#   'try',
#   'report',
#   'profile',
#   'a',
#   'catfish',
#   'use',
#   'someone',
#   'el',
#   'photo',
#   'deny',
#   'provide',
#   'detail'],
#  ['account',
#   'name',
#   'open',
#   'past',
#   'year',
#   'st',
#   'open',
#   'due',
#   'flair',
#   'm',
#   'able',
#   'check',
#   'phone',
#   'week',
#   'interest',
#   'facebook',
#   'find',
#   'man',
#   'take',
#   'account',
#   'pretend',
#   'facebook',
#   'able',
#   'get',
#   'contact',
#   'nightmare',
#   'begin',
#   'identity',
#   'theft',
#   'felt',
#   'rap',
#   'id',
#   'believe',
#   'facebook',
#   'safe',
#   'unfortunately',
#   'easy',
#   'access',
#   'people',
#   'this'],
#  ['facebook',
#   'app',
#   'wont',
#   'work',
#   'unless',
#   'allow',
#   'access',
#   'personal',
#   'phone',
#   'contact',
#   'storage',
#   'space',
#   'phone',
#   'violation',
#   'right',
#   'privacy',
#   'anyone',
#   'friend',
#   'family',
#   'member',
#   'contact',
#   'list',
#   'device',
#   'dont',
#   'want',
#   'information',
#   'share',
#   'identity',
#   'theft',
#   'fraud',
#   'cost',
#   'alot',
#   'credit',
#   'card',
#   'account',
#   'debit',
#   'cash',
#   'debt',
#   'due',
#   'lack',
#   'good',
#   'security',
#   'share',
#   'information',
#   'right',
#   'ask'],
#  ['well',
#   'catindahat',
#   'account',
#   'main',
#   'pic',
#   'long',
#   'remember',
#   'go',
#   'identity',
#   'theft',
#   'developer',
#   'moto',
#   'phone',
#   'decide',
#   'hack',
#   'every',
#   'account',
#   'try',
#   'make',
#   'since',
#   'get',
#   'chrome',
#   'book',
#   'ex',
#   'website',
#   'family',
#   'friend',
#   'misfit',
#   'want',
#   'keep',
#   'account',
#   'pic',
#   'match',
#   'finger',
#   'print',
#   'irs',
#   'track',
#   'card',
#   'hahahaha',
#   'enjoy',
#   'cuz',
#   'eventually',
#   'truth',
#   'well',
#   'lock'],
#  ['fineexcept',
#   'u',
#   'use',
#   'people',
#   'info',
#   'share',
#   'post',
#   'identity',
#   'theft',
#   'prefer',
#   'post',
#   'private',
#   'info'],
#  ['dont', 'respond', 'complaint', 'identity', 'theft'],
#  ['identity',
#   'theft',
#   'easy',
#   'one',
#   'steal',
#   'phone',
#   'let',
#   'alone',
#   'several',
#   'account',
#   'hijack',
#   'prosecute',
#   'others',
#   'action',
#   'post',
#   'manipulate',
#   'others',
#   'district',
#   'attorney',
#   'community',
#   'mor',
#   'corrupt',
#   'police',
#   'sheriff',
#   'get',
#   'salary',
#   'match',
#   'make',
#   'movie',
#   'nothing',
#   'like',
#   'honest',
#   'service',
#   'know',
#   'prosecute',
#   'innocent',
#   'person',
#   'protect',
#   'thier',
#   'guilty',
#   'process',
#   'server',
#   'ada',
#   'relative',
#   'elect',
#   'office',
#   'commit',
#   'drug',
#   'deal',
#   'burglary'],
#  ['honestly',
#   'one',
#   'least',
#   'helpful',
#   'company',
#   'account',
#   'get',
#   'hack',
#   'change',
#   'email',
#   'phone',
#   'number',
#   'option',
#   'help',
#   'center',
#   'require',
#   'know',
#   'email',
#   'phone',
#   'number',
#   'account',
#   'change',
#   'last',
#   'page',
#   'say',
#   'nothing',
#   'tell',
#   'create',
#   'new',
#   'account',
#   'shout',
#   'facebook',
#   'allow',
#   'identity',
#   'theft'],
#  ['again',
#   'update',
#   'provide',
#   'developer',
#   'yet',
#   'information',
#   'pertain',
#   'exactly',
#   'update',
#   'provide',
#   'facebook',
#   'legal',
#   'obligation',
#   'user',
#   'transparent',
#   'update',
#   'provide',
#   'information',
#   'regard',
#   'this',
#   'give',
#   'facebooks',
#   'ability',
#   'create',
#   'access',
#   'enforce',
#   'permission',
#   'others',
#   'category',
#   'neither',
#   'delete',
#   'revoke',
#   'platform',
#   'facilitate',
#   'identity',
#   'theft',
#   'steal',
#   'trillion',
#   'attempt',
#   'relocate',
#   'overseas'],
#  ['proactive',
#   'update',
#   'me',
#   'something',
#   'wrong',
#   'respond',
#   'positive',
#   'response',
#   'identity',
#   'theft',
#   'secure',
#   'account',
#   'give',
#   'access',
#   'world',
#   'able',
#   'reach',
#   'out',
#   'break',
#   'phone',
#   'root',
#   'it',
#   'facebook',
#   'understand',
#   'plane',
#   'english',
#   'help',
#   'keep',
#   'account',
#   'mine'],
#  ['anything',
#   'people',
#   'make',
#   'threat',
#   'murder',
#   'rape',
#   'you',
#   'im',
#   'get',
#   'message',
#   'explicit',
#   'image',
#   'hack',
#   'account',
#   'delete',
#   'catfish',
#   'account',
#   'people',
#   'enjoy',
#   'follow',
#   'disappear',
#   'list',
#   'without',
#   'explanation',
#   'ive',
#   'mute',
#   'twice',
#   'without',
#   'explanation',
#   'comment',
#   'threat',
#   'language',
#   'insult',
#   'allow',
#   'contest',
#   'them',
#   'get',
#   'ad',
#   'thing',
#   'talk',
#   'people',
#   'inperson',
#   'them'],
#  ['get', 'catfished'],
#  ['day',
#   'dude',
#   'use',
#   'pic',
#   'catfish',
#   'chick',
#   'report',
#   'facebook',
#   'facebook',
#   'say',
#   'nothing',
#   'fishy',
#   'pageprofile',
#   'even',
#   'explain',
#   'whole',
#   'situation',
#   'fact',
#   'proof',
#   'identity',
#   'next',
#   'thing',
#   'know',
#   'whole',
# ...
#   'platform',
#   'trend',
#   'also',
#   'issue',
#   'since',
#   'get',
#   'increasingly',
#   'dangerous'],
#  ['app',
#   'good',
#   'user',
#   'share',
#   'inappropriate',
#   'video',
#   'violate',
#   'environment',
#   'thats',
#   'like',
#   'request',
#   'tiktok',
#   'team',
#   'improve',
#   'platform',
#   'also',
#   'support',
#   'small',
#   'user'],
#  ['nice',
#   'app',
#   'recommend',
#   'kid',
#   'bc',
#   'bad',
#   'like',
#   'swear',
#   'word',
#   'bad',
#   'swear',
#   'song',
#   'bad',
#   'thing',
#   'good',
#   'job',
#   'make',
#   'app'],
#  ['pedophile',
#   'everywhere',
#   'absolutely',
#   'disgust',
#   'content',
#   'predatory',
#   'behavior',
#   'content',
#   'maker',
#   'app',
#   'unsafe',
#   'child'],
#  ['there',
#   'many',
#   'sexual',
#   'video',
#   'might',
#   'well',
#   'call',
#   'pornhub',
#   'junior'],
#  ['app',
#   'great',
#   'lot',
#   'kid',
#   'app',
#   'lot',
#   'inappropriate',
#   'stuff',
#   'too',
#   'dont',
#   'really',
#   'want',
#   'kid',
#   'kind',
#   'stuff',
#   'im',
#   'year',
#   'old',
#   'mom',
#   'people',
#   'age',
#   'would',
#   'well',
#   'app',
#   'year',
#   'old'],
#  ['love', 'app', 'think', 'inappropriate', 'video', 'r', 'family', 'friendly'],
#  ['app',
#   'fun',
#   'good',
#   'bad',
#   'thing',
#   'dont',
#   'like',
#   'inappropriate',
#   'thing',
#   'creep',
#   'also',
#   'hate',
#   'lag',
#   'glitch',
#   'one',
#   'lag',
#   'even',
#   'log',
#   'account',
#   'cant',
#   'get',
#   'back',
#   'also',
#   'dont',
#   'like',
#   'negativity'],
#  ['app',
#   'dosent',
#   'support',
#   'watch',
#   'bad',
#   'video',
#   'porno',
#   'others',
#   'support',
#   'kid'],
#  ['video', 'inappropriate', 'child'],
#  ['amaze', 'inappropriate', 'behavior', 'overall', 'good', 'app', 'use'],
#  ['seem',
#   'full',
#   'either',
#   'ppl',
#   'advertising',
#   'fan',
#   'page',
#   'indivuals',
#   'dangerous',
#   'act',
#   'really',
#   'getying',
#   'annoy',
#   'app',
#   'now'],
#  ['app',
#   'need',
#   'work',
#   'rat',
#   'e',
#   'everyone',
#   'consider',
#   'app',
#   'adult',
#   'it',
#   'however',
#   'guideline',
#   'clear',
#   'enough',
#   'understand'],
#  ['straight', 'trash', 'remove', 'dangerous', 'racist', 'content'],
#  ['tik',
#   'tok',
#   'great',
#   'unique',
#   'app',
#   'laggy',
#   'month',
#   'tik',
#   'tok',
#   'app',
#   'long',
#   'work',
#   'open',
#   'app',
#   'useit',
#   'whenever',
#   'would',
#   'crash',
#   'device',
#   'id',
#   'restart',
#   'it',
#   'also',
#   'lot',
#   'interest',
#   'thing',
#   'appear',
#   'tik',
#   'tok',
#   'lot',
#   'youg',
#   'child',
#   'use',
#   'tik',
#   'tok',
#   'expose',
#   'thing',
#   'tik',
#   'tok',
#   'dangerous',
#   'young',
#   'child',
#   'download',
#   'tik',
#   'tok',
#   'fun'],
#  ['little',
#   'inappropriate',
#   'song',
#   'dance',
#   'express',
#   'true',
#   'self',
#   'best'],
#  ['enjoyable',
#   'app',
#   'quite',
#   'fun',
#   'find',
#   'gory',
#   'inappropriate',
#   'video',
#   'circulate',
#   'app',
#   'ive',
#   'come',
#   'across',
#   's',
#   'x',
#   'video',
#   'wich',
#   'quite',
#   'disgust'],
#  ['hate',
#   'tik',
#   'tok',
#   'family',
#   'friendly',
#   'app',
#   'much',
#   'inappropriate',
#   'content',
#   'dance',
#   'tik',
#   'tok'],
#  ['bad',
#   'application',
#   'incite',
#   'immorality',
#   'please',
#   'delete',
#   'order',
#   'preserve',
#   'generation',
#   'unethical',
#   'application'],
#  ['tik',
#   'tok',
#   'follow',
#   'moderation',
#   'guideline',
#   'content',
#   'know',
#   'leave',
#   'hate',
#   'speech',
#   'illegal',
#   'activity',
#   'take',
#   'people',
#   'ask',
#   'reason',
#   'report',
#   'illegal',
#   'unethical',
#   'video',
#   'content'],
#  ['saw', 'guy', 'kill'],
#  ['unethical',
#   'cant',
#   'control',
#   'news',
#   'fee',
#   'preference',
#   'know',
#   'come',
#   'next',
#   'disgrace',
#   'family',
#   'surround'],
#  ['communist',
#   'spy',
#   'app',
#   'plus',
#   'lot',
#   'illegal',
#   'unethical',
#   'content',
#   'kid',
#   'expose',
#   'kind',
#   'medium',
#   'ruin',
#   'value'],
#  ['app',
#   'great',
#   'problem',
#   'young',
#   'kid',
#   'also',
#   'people',
#   'say',
#   'mean',
#   'thing',
#   'people',
#   'put',
#   'people',
#   'allow',
#   'please',
#   'find',
#   'way',
#   'fix'],
#  ['tiktok', 'great', 'community', 'profile', 'picture', 'inappropriate'],
#  ['amaze', 'good', 'inappropriate', 'stuff', 'good'],
#  ['app',
#   'dumb',
#   'ive',
#   'never',
#   'ive',
#   'already',
#   'content',
#   'inappropriate',
#   'content',
#   'shove',
#   'face',
#   'quite',
#   'literally',
#   'every',
#   'social',
#   'medium',
#   'think',
#   'of',
#   'think',
#   'annoying',
#   'cant',
#   'even',
#   'run',
#   'it',
#   'bc',
#   'see',
#   'every',
#   'post',
#   'see',
#   'internet',
#   'bunch',
#   'crazy',
#   'insane',
#   'thing',
#   'happen',
#   'there',
#   'smh'],
#  ['really',
#   'good',
#   'thing',
#   'make',
#   'friend',
#   'also',
#   'good',
#   'kid',
#   'like',
#   'year',
#   'old',
#   'like',
#   'cuss',
#   'word',
#   'read',
#   'parent',
#   'let',
#   'kid',
#   'install',
#   'theyre',
#   'age',
#   'say',
#   'suppose',
#   'thank',
#   'unless',
#   'mature',
#   'yeah',
#   'make',
#   'sure',
#   'see',
#   'summer',
#   'video',
#   'cannot',
#   'understand',
#   'inappropriate',
#   'thank'],
#  ['hate',
#   'fact',
#   'dont',
#   'live',
#   'button',
#   'everyone',
#   'go',
#   'live',
#   'plus',
#   'hate',
#   'video',
#   'inappropriate',
#   'sexual',
#   'povs',
#   'make',
#   'sick',
#   'take',
#   'video',
#   'safety',
#   'sicors',
#   'those',
#   'tiktok',
#   'problrems'],
#  ['much',
#   'racial',
#   'violence',
#   'allow',
#   'much',
#   'police',
#   'show',
#   'beat',
#   'black',
#   'allow',
#   'disable',
#   'people',
#   'bully',
#   'pedophile',
#   'app',
#   'tik',
#   'tok',
#   'emotionally',
#   'motivate',
#   'change',
#   'life',
#   'hope',
#   'improve',
#   'come',
#   'back',
#   'black',
#   'people',
#   'funny',
#   'l',
#   'l'],
#  ['use',
#   'love',
#   'app',
#   'hundred',
#   'literally',
#   'u',
#   'report',
#   'video',
#   'guy',
#   'genitals',
#   'out',
#   'fondling',
#   'himself',
#   'tiktok',
#   'leave',
#   'another',
#   'hour',
#   'say',
#   'violation',
#   'guideline',
#   'completely',
#   'irresponsible',
#   'know',
#   'lot',
#   'child',
#   'use',
#   'app',
#   'well'],
#  ['really',
#   'like',
#   'tiktok',
#   'n',
#   'page',
#   'do',
#   'good',
#   'need',
#   'b',
#   'rat',
#   'nude',
#   'link',
#   'post',
#   'profile',
#   'kid',
#   'see',
#   'think',
#   'tiktok',
#   'need',
#   'take',
#   'responsibility',
#   'situation',
#   'like'],
#  ['noone',
#   'monitor',
#   'anything',
#   'inappropriate',
#   'content',
#   'post',
#   'much',
#   'bad',
#   'influence',
#   'kid',
#   'even',
#   'grow',
#   'up',
#   'go',
#   'review',
#   'section',
#   'go',
#   'star',
#   'rat',
#   'check',
#   'tiktok',
#   'reply',
#   'unsatisfied',
#   'customer',
#   'copy',
#   'paste',
#   'reply',
#   'dont',
#   'care',
#   'anyone',
#   'write',
#   'issue',
#   'tiktok',
#   'number',
#   'verify',
#   'cannot',
#   'access',
#   'number',
#   'option',
#   'change',
#   'number',
#   'month',
#   'since',
#   'write',
#   'ticket',
#   'noone',
#   'reply',
#   'yet'],
#  ['saw',
#   'video',
#   'dog',
#   'die',
#   'app',
#   'report',
#   'get',
#   'notification',
#   'hour',
#   'late',
#   'say',
#   'violate',
#   'term',
#   'service'],
#  ['allow',
#   'type',
#   'bigotry',
#   'rampant',
#   'racism',
#   'homophobia',
#   'sexism',
#   'ableism',
#   'much',
#   'make',
#   'app',
#   'toxic',
#   'theyd',
#   'hold',
#   'people',
#   'accountable',
#   'could',
#   'wonderful',
#   'app',
#   'unfortunately',
#   'stand',
#   'cant',
#   'rate',
#   'high',
#   'get',
#   'together',
#   'tiktok',
#   'bigotry',
#   'place',
#   'today',
#   'society'],
#  ['recommend',
#   'app',
#   'boring',
#   'video',
#   'get',
#   'wow',
#   'effect',
#   'extreme',
#   'thing',
#   'be',
#   'show',
#   'animal',
#   'crueltya',
#   'responsible',
#   'app',
#   'allow',
#   'video',
#   'keep',
#   'app',
#   'long'],
#  ['rampant',
#   'homophobia',
#   'transphobia',
#   'racism',
#   'pedophilia',
#   'animal',
#   'abuse',
#   'multiple',
#   'problem',
#   'accountability'],
#  ['first',
#   'underage',
#   'child',
#   'app',
#   'watch',
#   'video',
#   'adult',
#   'female',
#   'twerking',
#   'adult',
#   'talk',
#   'sexual',
#   'subject',
#   'ive',
#   'try',
#   'several',
#   'time',
#   'dispute',
#   'nothing',
#   'ever',
#   'happen',
#   'term',
#   'service',
#   'state',
#   'user',
#   'account',
#   'unless',
#   'supervise',
#   'adult',
#   'know',
#   'happen',
#   'feel',
#   'time',
#   'guy',
#   'actually',
#   'step',
#   'idk',
#   'job',
#   'remove',
#   'account',
#   'parent',
#   'join',
#   'together',
#   'handle',
#   'it'],
#  ['guy',
#   'responsible',
#   'becouse',
#   'dont',
#   'take',
#   'dangerous',
#   'video',
#   'down',
#   'thats',
#   'give',
#   'star'],
#  ['app',
#   'good',
#   'funny',
#   'kid',
#   'lot',
#   'inappropriate',
#   'content',
#   'therefore',
#   'believe',
#   'tiktok',
#   'good',
#   'app',
#   'responsible',
#   'kid',
#   'age',
#   'although',
#   'plenty',
#   'inappropriate',
#   'content',
#   'also',
#   'great',
#   'place',
#   'learn',
#   'feel',
#   'encourage',
#   'yeah',
#   'way',
#   'hurt',
#   'people',
#   'thanks',
#   'god',
#   'back',
#   'huge',
#   'phone',
#   'tik',
#   'tok',
#   'huh',
#   'w',
#   'conclude',
#   'say',
#   'app',
#   'best',
#   'app'],
#  ['watch',
#   'video',
#   'someone',
#   'brew',
#   'catnip',
#   'tea',
#   'put',
#   'water',
#   'bowel',
#   'thats',
#   'animal',
#   'abuse',
#   'sick',
#   'demented',
#   'people',
#   'gonna',
#   'start',
#   'stupid',
#   'thing',
#   'animal',
#   'view',
#   'stupid',
#   'app',
#   'thats',
#   'include',
#   'stupid',
#   'thing',
#   'kid',
#   'cause',
#   'seriously',
#   'hurt',
#   'view',
#   'irresponsible',
#   'site',
#   'im',
#   'extremely',
#   'mad',
#   'look',
#   'law',
#   'animal',
#   'abuse',
#   'see',
#   'apply'],
#  ['ive',
#   'write',
#   'review',
#   'problem',
#   'fix',
#   'problem',
#   'moderation',
#   'report',
#   'work',
#   'someone',
#   'basically',
#   'javascript',
#   'cookie',
#   'grabber',
#   'report',
#   'videoaccount',
#   'wouldnt',
#   'take',
#   'down',
#   'someone',
#   'literally',
#   'twerking',
#   'video',
#   'report',
#   'yall',
#   'wouldnt',
#   'take',
#   'down',
#   'someone',
#   'make',
#   'graphic',
#   'sexual',
#   'stuff',
#   'would',
#   'take',
#   'wouldnt',
#   'go',
#   'steal',
#   'content',
#   'please',
#   'fix',
#   'this'],
#  ['good',
#   'app',
#   'amaze',
#   'content',
#   'unfortunately',
#   'star',
#   'only',
#   'report',
#   'video',
#   'steal',
#   'content',
#   'violent',
#   'graphic',
#   'pornography',
#   'nudity',
#   'include',
#   'minor',
#   'safety',
#   'review',
#   'report',
#   'say',
#   'doesnt',
#   'violate',
#   'community',
#   'guideline',
#   'read',
#   'clearly',
#   'video',
#   'report',
#   'mean',
#   'tik',
#   'tok',
#   'actually',
#   'endorse',
#   'video',
#   'ive',
#   'report',
#   'tik',
#   'tok',
#   'need',
#   'fire',
#   'moderator'],
#  ['report',
#   'video',
#   'steal',
#   'content',
#   'nudity',
#   'graphic',
#   'content',
#   'etc',
#   'nothimg',
#   'do',
#   'receive',
#   'message',
#   'state',
#   'we',
#   'review',
#   'video',
#   'nothing',
#   'violate',
#   'community',
#   'guideline',
#   'crappy',
#   'report',
#   'system'],
#  ['okay',
#   'app',
#   'awesome',
#   'iv',
#   'work',
#   'hard',
#   'k',
#   'follower',
#   'without',
#   'tiktok',
#   'ill',
#   'nothing',
#   'right',
#   'stuff',
#   'fypso',
#   'girl',
#   'make',
#   'inappropriate',
#   'video',
#   'report',
#   'ppl',
#   'bully',
#   'post',
#   'video',
#   'get',
#   'take',
#   'mean',
#   'bully',
#   'anything',
#   'like',
#   'that'],
#  ['app',
#   'good',
#   'really',
#   'fun',
#   'but',
#   'see',
#   'really',
#   'inapropriate',
#   'thing',
#   'here',
#   'kid',
#   'get',
#   'bully',
#   'lot'],
#  ['noone',
#   'monitor',
#   'anything',
#   'inappropriate',
#   'content',
#   'post',
#   'much',
#   'bad',
#   'influence',
#   'kid',
#   'even',
#   'grow',
#   'up',
#   'go',
#   'review',
#   'section',
#   'go',
#   'star',
#   'rat',
#   'check',
#   'tiktok',
#   'reply',
#   'unsatisfied',
#   'customer',
#   'copy',
#   'paste',
#   'reply',
#   'dont',
#   'care',
#   'anyone',
#   'write',
#   'issue',
#   'tiktok',
#   'number',
#   'verify',
#   'cannot',
#   'access',
#   'number',
#   'option',
#   'change',
#   'number',
#   'month',
#   'since',
#   'write',
#   'ticket',
#   'noone',
#   'reply',
#   'yet'],
#  ['full',
#   'overly',
#   'sexualise',
#   'video',
#   'young',
#   'woman',
#   'delete',
#   'yewtree',
#   'task',
#   'force',
#   'come',
#   'knock'],
#  ['please', 'bain', 'video', 'smoking'],
#  ['bad', 'much', 'nudity'],
#  ['dont',
#   'take',
#   'nudity',
#   'rule',
#   'seriously',
#   'son',
#   'addict',
#   'p',
#   'rn',
#   'app',
#   'please',
#   'dont',
#   'install',
#   'app',
#   'corrupt',
#   'child',
#   'make',
#   'horny'],
#  ['bad',
#   'quality',
#   'camera',
#   'layout',
#   'option',
#   'available',
#   'android',
#   'never',
#   'get',
#   'response',
#   'tiktok',
#   'dangerous',
#   'activity',
#   'privacy',
#   'control',
#   'sexual',
#   'content',
#   'tiktok',
#   'review',
#   'report',
#   'block',
#   'video',
#   'acounts',
#   'get',
#   'report',
#   'hater',
#   'app',
#   'get',
#   'stake',
#   'ad',
#   'even',
#   'update',
#   'update',
#   'important',
#   'tiktok'],
#  ['nice',
#   'app',
#   'entertainment',
#   'bad',
#   'people',
#   'use',
#   'create',
#   'sexual',
#   'comtent'],
#  ['bad', 'app', 'nudity', 'sexual', 'experience'],
#  ['app',
#   'encourage',
#   'minor',
#   'sexualize',
#   'body',
#   'others',
#   'bad',
#   'part',
#   'tiktok',
#   'cover',
#   'up',
#   'know',
#   'ive',
#   'write',
#   'type',
#   'review',
#   'take',
#   'down',
#   'pathetic'],
#  ['many', 'people', 'show', 'nudity', 'pfps'],
#  ['oversexualizing', 'underage', 'girl'],
#  ['delete', 'app', 'spread', 'vulgarity', 'nudity'],
#  ['fatphobic',
#   'app',
#   'use',
#   'app',
#   'police',
#   'fat',
#   'body',
#   'nudity',
#   'skinny',
#   'body',
#   'exact',
#   'nudity',
#   'same',
#   'bra',
#   'underwear',
#   'set',
#   'fat',
#   'person',
#   'video',
#   'get',
#   'take',
#   'down',
#   'skinny',
#   'girl',
#   'didnt',
#   'pick',
#   'choose',
#   'support',
#   'inclusive'],
#  ['upload', 'sexual', 'contant'],
#  ['stop', 'sexualize', 'underaged', 'girl', 'pedophile', 'love', 'app'],
#  ['way', 'sexualize'],
#  ['kid',
#   'app',
#   'many',
#   'nude',
#   'sexual',
#   'stuff',
#   'could',
#   'text',
#   'people',
#   'many',
#   'dangerous',
#   'organization',
#   'way',
#   'many',
#   'deadly',
#   'challenge',
#   'hate',
#   'app',
#   'especially',
#   'kid'],
#  ['best',
#   'app',
#   'short',
#   'entertainment',
#   'video',
#   'lack',
#   'important',
#   'feature',
#   'like',
#   'scroll',
#   'feature',
#   'video',
#   'playlist',
#   'why',
#   'need',
#   'search',
#   'entire',
#   'profile',
#   'find',
#   'part',
#   'part',
#   'video',
#   'law',
#   'scammer',
#   'people',
#   'scam',
#   'sake',
#   'increase',
#   'follower',
#   'low',
#   'filteration',
#   'sexual',
#   'content',
#   'etc'],
#  ['lol',
#   'guy',
#   'delete',
#   'review',
#   'much',
#   'nudity',
#   'dark',
#   'video',
#   'child',
#   'app',
#   'fix',
#   'damn',
#   'community',
#   'guildlines',
#   'guy',
#   'literally',
#   'take',
#   'every',
#   'video',
#   'one',
#   'need',
#   'take',
#   'down'],
#  ['nudity', 'everywhere', 'bad', 'child'],
#  ['love', 'dance', 'soooo', 'great', 'hate', 'nude', 'page'],
#  ['welcome',
#   'st',
#   'century',
#   'sex',
#   'free',
#   'love',
#   'costly',
#   'loose',
#   'phone',
#   'painful',
#   'loose',
#   'virginity',
#   'modernization',
#   'mean',
#   'nudity',
#   'drinksmoke',
#   'old',
#   'fashion',
#   'boy',
#   'flirt',
#   'pass',
#   'bad',
#   'comment',
#   'girl',
#   'cheat',
#   'partner',
#   'sharp',
#   'temple',
#   'turn',
#   'date',
#   'point',
#   'worship',
#   'god',
#   'difficult',
#   'lie',
#   'turn',
#   'reality',
#   'lady',
#   'fear',
#   'pregnancy',
#   'hiv',
#   'pizza',
#   'de'],
#  ['encourage', 'nudity', 'sexual', 'scene', 'adult', 'childrens'],
#  ['tiktok',
#   'dose',
#   'bounderys',
#   'never',
#   'respond',
#   'im',
#   'lokey',
#   'glad',
#   'get',
#   'take',
#   'dont',
#   'care',
#   'people',
#   'smoking',
#   'drug',
#   'video',
#   'fake',
#   'blood',
#   'fx',
#   'makeup',
#   'truley',
#   'isnt',
#   'ok',
#   'verifecation',
#   'verifidewhy',
#   'stupid',
#   'like',
#   'one',
#   'well',
#   'another',
#   'person',
#   'last',
#   'thing',
#   'black',
#   'people',
#   'cummunity',
#   'take',
#   'thier',
#   'video',
#   'know',
#   'fix',
#   'something',
#   'like',
#   'cant',
#   'fix',
#   'sick'],
#  ['full',
#   'bug',
#   'full',
#   'sexual',
#   'content',
#   'full',
#   'pedophile',
#   'full',
#   'stuff',
#   'want',
#   'see',
#   'choose',
#   'content',
#   'precisely',
#   'see',
#   'naked',
#   'dude',
#   'girl',
#   'daily',
#   'basis',
#   'maki',
#   'sexual',
#   'content',
#   'talk',
#   'sex',
#   'absolutely',
#   'pathetic',
#   'plus',
#   'there',
#   'ton',
#   'animal',
#   'abuse',
#   'ton',
#   'scammer',
#   'sad',
#   'story',
#   'app',
#   'full',
#   'gross',
#   'people',
#   'psychopath',
#   'use',
#   'nicefundecent',
#   'app',
#   'show',
#   'body',
#   'talk',
#   'sex',
#   'chance',
#   'survive',
#   'app'],
#  ['app',
#   'garbage',
#   'fill',
#   'people',
#   'sexual',
#   'eiyh',
#   'underage',
#   'child',
#   'watch',
#   'it',
#   'parent',
#   'read',
#   'this',
#   'allow',
#   'kid',
#   'get',
#   'it'],
#  ['allow',
#   'nudity',
#   'report',
#   'doesnt',
#   'violate',
#   'community',
#   'guideline',
#   'guideline',
#   'say',
#   'allow'],
#  ...]

# %%
#For Apriori algorithm, this dataset needs to be one-hot encoded.
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(corpus_list).transform(corpus_list)
corpus_df = pd.DataFrame(te_ary, columns=te.columns_)
corpus_df
# Out:
#           a     aa    aap     ab  abbreviate  ability   able  ableism  \
# 0     False  False  False  False       False    False  False    False
# 1     False  False  False  False       False    False  False    False
# 2     False  False  False  False       False    False  False    False
# 3     False  False  False  False       False    False  False    False
# 4     False  False  False  False       False    False  False    False
# ...     ...    ...    ...    ...         ...      ...    ...      ...
# 1917  False  False  False  False       False    False  False    False
# 1918  False  False  False  False       False    False  False    False
# 1919  False  False  False  False       False    False  False    False
# 1920  False  False  False  False       False    False  False    False
# 1921  False  False  False  False       False    False  False    False
#
#       ableist  aboslutely  ...     yu    zac  zayanbutt   zero  zindabad  \
# 0       False       False  ...  False  False      False  False     False
# 1       False       False  ...  False  False      False  False     False
# 2       False       False  ...  False  False      False  False     False
# 3       False       False  ...  False  False      False  False     False
# 4       False       False  ...  False  False      False  False     False
# ...       ...         ...  ...    ...    ...        ...    ...       ...
# 1917    False       False  ...  False  False      False  False     False
# 1918    False       False  ...  False  False      False  False     False
# 1919    False       False  ...  False  False      False  False     False
# 1920    False       False  ...  False  False      False  False     False
# 1921    False       False  ...  False  False      False  False     False
#
#        zone   zoom  zoomyesterday   zuck  zuckerberg
# 0     False  False          False  False       False
# 1     False  False          False  False       False
# 2     False  False          False  False       False
# 3     False  False          False  False       False
# 4     False  False          False  False       False
# ...     ...    ...            ...    ...         ...
# 1917  False  False          False  False       False
# 1918  False  False          False  False       False
# 1919  False  False          False  False       False
# 1920  False  False          False  False       False
# 1921  False   True          False  False       False
#
# [1922 rows x 4805 columns]

# %%
#rule = apriori(transactions = corpus_list, min_support = 0.005, min_confidence = 0.05, min_lift = 3, min_length = 2, max_length = 2)
from mlxtend.frequent_patterns import apriori
import time
start_time = time.time()
frequent_itemsets = apriori(corpus_df, min_support = 0.003, use_colnames=True)
print("---Runtime: %s seconds ---" % (time.time() - start_time))
#API: apriori(df, min_support=0.5, use_colnames=False, max_len=None, verbose=0, low_memory=False)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
print("the number of frequent itemsets generated:", len(frequent_itemsets))
frequent_itemsets
# Out:
# ---Runtime: 30.173851013183594 seconds ---
# the number of frequent itemsets generated: 15746
#         support                                           itemsets  length
# 0      0.003122                                                (a)       1
# 1      0.017170                                             (able)       1
# 2      0.004162                                            (about)       1
# 3      0.003122                                         (absolute)       1
# 4      0.018210                                       (absolutely)       1
# ...         ...                                                ...     ...
# 15741  0.004683  (violate, guideline, report, community, video,...       6
# 15742  0.003642  (violate, guideline, content, report, video, app)       6
# 15743  0.003122         (uber, trip, cancel, even, charge, driver)       6
# 15744  0.004162  (violate, guideline, content, report, communit...       6
# 15745  0.003122  (violate, guideline, content, report, communit...       7
#
# [15746 rows x 3 columns]

# %% [markdown]
# 1. Support - It is the measure of frequency or abundance of an item in a dataset. It can be 'antecedent support', 'consequent support', and 'support'. 'antecedent support' contains proportion of transactions done for the antecedent while 'consequent support' involves those for consequent. 'Support' is computed for both antecedent and consequent in question.
# 2. Confidence - This gives the probability of consequent in a transaction given the presence of antecedent.
# 3. Lift - Given that antecedents and consequents are independent, how often do they come together/bought together.
# 4. Leverage - It is the difference between frequency of antecedent and consequent together in transactions to frequency of both in independent transactions.
# 5. Conviction - A higher conviction score means that consequent is highly dependent on antecedent.

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=9)
#rules.antecedents = rules.antecedents.apply(lambda x: next(iter(x)))
#rules.consequents = rules.consequents.apply(lambda x: next(iter(x)))
rules
#display(rules)
# Out:
#            antecedents                                        consequents  \
# 0             (access)                                           (cannot)
# 1             (cannot)                                           (access)
# 2           (password)                                           (access)
# 3             (access)                                         (password)
# 4      (accessibility)                                          (caption)
# ...                ...                                                ...
# 12455        (violate)  (guideline, content, report, community, video,...
# 12456      (guideline)  (violate, content, report, community, video, app)
# 12457        (content)  (violate, guideline, report, community, video,...
# 12458         (report)  (violate, guideline, content, community, video...
# 12459      (community)  (violate, guideline, content, report, video, app)
#
#        antecedent support  consequent support   support  confidence  \
# 0                0.037981            0.022373  0.013528    0.356164
# 1                0.022373            0.037981  0.013528    0.604651
# 2                0.005723            0.037981  0.003642    0.636364
# 3                0.037981            0.005723  0.003642    0.095890
# 4                0.007284            0.007284  0.005203    0.714286
# ...                   ...                 ...       ...         ...
# 12455            0.027575            0.003122  0.003122    0.113208
# 12456            0.037461            0.003122  0.003122    0.083333
# 12457            0.072841            0.004683  0.003122    0.042857
# 12458            0.083767            0.003122  0.003122    0.037267
# 12459            0.047347            0.003642  0.003122    0.065934
#
#             lift  leverage  conviction
# 0      15.919720  0.012678    1.518443
# 1      15.919720  0.012678    2.433341
# 2      16.754670  0.003425    2.645552
# 3      16.754670  0.003425    1.099730
# 4      98.061224  0.005150    3.474506
# ...          ...       ...         ...
# 12455  36.264151  0.003036    1.124139
# 12456  26.694444  0.003005    1.087504
# 12457   9.152381  0.002781    1.039884
# 12458  11.937888  0.002860    1.035467
# 12459  18.103611  0.002949    1.066689
#
# [12460 rows x 9 columns]

# %%
# Generate scatterplot using support and confidence
plt.figure(figsize=(10,6))
sns1.scatterplot(x = "support", y = "confidence", data = rules)
plt.margins(0.01,0.01)
plt.show()

# %%
# Generate scatterplot using support and confidence
plt.figure(figsize=(10,6))
sns1.scatterplot(x = "support", y = "confidence", 
                size = "lift", data = rules)
plt.margins(0.01,0.01)
plt.show()

# %%
# Transform the DataFrame of rules into a matrix using the lift metric
import seaborn as sns1
rules_top = rules.nlargest(n = 20, columns = 'lift')

pivot = rules_top.pivot(index = 'consequents', 
                    columns = 'antecedents', values= 'lift')

# Generate a heatmap with annotations on and the colorbar off
plt.figure(figsize=(10,6))
sns1.heatmap(pivot, annot = True, cbar = False)
b, t = plt.ylim() 
b += 0.5 
t -= 0.5 
plt.ylim(b, t) 
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
# Transform antecedent, consequent, and support columns into matrix
support_table = rules_top.pivot(index='consequents', columns='antecedents', values='support')

plt.figure(figsize=(10,6))
sns1.heatmap(support_table, annot=True, cbar=False)
b, t = plt.ylim() 
b += 0.5 
t -= 0.5 
plt.ylim(b, t) 
plt.yticks(rotation=0)
plt.show()

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=9)
rules.antecedents = rules.antecedents.apply(lambda x: next(iter(x)))
rules.consequents = rules.consequents.apply(lambda x: next(iter(x)))
rules_top = rules.nlargest(n = 5, columns = 'lift')

import networkx as nx
fig, ax=plt.subplots(figsize=(10,4))
first_choice=nx.from_pandas_edgelist(rules_top,source='antecedents',target='consequents', create_using = nx.MultiDiGraph(), edge_attr='lift')

nx.draw(GA, with_labels=True)
plt.show()

# %%
rules_top
# Out:
#       antecedents consequents  antecedent support  consequent support  \
# 7683    guideline   community            0.003642            0.004162
# 7686    community   guideline            0.004162            0.003642
# 8043      disable    platform            0.004162            0.003642
# 8046     platform     disable            0.003642            0.004162
# 11531        make   guideline            0.004162            0.003642
#
#         support  confidence        lift  leverage  conviction
# 7683   0.003122    0.857143  205.928571  0.003107    6.970864
# 7686   0.003122    0.750000  205.928571  0.003107    3.985432
# 8043   0.003122    0.750000  205.928571  0.003107    3.985432
# 8046   0.003122    0.857143  205.928571  0.003107    6.970864
# 11531  0.003122    0.750000  205.928571  0.003107    3.985432
